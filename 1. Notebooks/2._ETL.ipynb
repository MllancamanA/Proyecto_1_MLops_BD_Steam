# %%
import pandas as pd
import numpy as np
from IPython.display import display
import json
import re

# %% [markdown]
# ## 1. Carga y visualización de datasets

# %%
# carga raw_reviews.parquet
df_reviews= pd.read_parquet(r'C:\Users\Lenovo\Desktop\Proyecto Individual\Datasets\0. Data\raw_reviews.parquet')

# %%
# carga raw_items.parquet
df_items= pd.read_parquet(r'C:\Users\Lenovo\Desktop\Proyecto Individual\Datasets\0. Data\raw_items.parquet')

# %%
# carga raw_games.parquet
df_games = pd.read_json(r'C:\Users\Lenovo\Desktop\Proyecto Individual\Datasets\0. Data\raw_games.json', lines=True)

# %%
# Echamos un vistazo a df_reviews
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'helpful': 'No ratings yet', 'i...
# 1  [{'funny': '', 'helpful': '15 of 20 people (75...
# 2  [{'funny': '', 'helpful': 'No ratings yet', 'i...
# 3  [{'funny': '', 'helpful': '2 of 2 people (100%...
# 4  [{'funny': '3 people found this review funny',...

# %%
# Revisamos la visualización de df_items
df_items.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %%
# por último, revisamos la visualización de df_steam
df_games.head()
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url specs  \
# 0      None   None     None  None  None         None  None        None  None
# 1      None   None     None  None  None         None  None        None  None
# 2      None   None     None  None  None         None  None        None  None
# 3      None   None     None  None  None         None  None        None  None
# 4      None   None     None  None  None         None  None        None  None
#
#   price  early_access  id developer
# 0  None           NaN NaN      None
# 1  None           NaN NaN      None
# 2  None           NaN NaN      None
# 3  None           NaN NaN      None
# 4  None           NaN NaN      None

# %% [markdown]
# ## 1. ETL df_reviews

# %%
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'helpful': 'No ratings yet', 'i...
# 1  [{'funny': '', 'helpful': '15 of 20 people (75...
# 2  [{'funny': '', 'helpful': 'No ratings yet', 'i...
# 3  [{'funny': '', 'helpful': '2 of 2 people (100%...
# 4  [{'funny': '3 people found this review funny',...

# %% [markdown]
# *Se crea copia para realizar las transformaciones*

# %%
df_reviews_copy = df_reviews.copy() # Hacemos una copia del DataFrame para hacer modificaciones del ETL

# %%
#revisamos los tipos de datos

df_reviews_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25799 entries, 0 to 25798
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   25799 non-null  object
#  1   user_url  25799 non-null  object
#  2   reviews   25799 non-null  object
# dtypes: object(3)
# memory usage: 604.8+ KB

# %% [markdown]
# Desanidado de reviews

# %%
# Trabajamos con extraer los datos de la columna reviews, ya que viene anidada

df_reviews_copy['reviews'][25798][0:]
# Out:
# array([{'funny': '1 person found this review funny', 'helpful': '1 of 2 people (50%) found this review helpful', 'item_id': '273110', 'last_edited': '', 'posted': 'Posted July 3.', 'recommend': True, 'review': 'had so much fun plaing this and collecting resources xD we won on my first try and killed final boss!'},
#        {'funny': '', 'helpful': 'No ratings yet', 'item_id': '730', 'last_edited': '', 'posted': 'Posted July 20.', 'recommend': True, 'review': ':D'},
#        {'funny': '', 'helpful': 'No ratings yet', 'item_id': '440', 'last_edited': '', 'posted': 'Posted July 2.', 'recommend': True, 'review': 'so much fun :D'}],
#       dtype=object)

# %% [markdown]
# Al revisar estos datos, en conjunto con el diccionario de datos disponible, se puede entender que este datasets guarda de forma anidada todos los reviews realizados por éste para diferentes ítems
# (videojuegos), que es información que necesitamos desagregar para crear las funciones solicitadas.
# Se procede a trabajar en este desanidado.

# %%
# Crea función convert_to_list para verificar si los datos en 'reviews' son listas o cadenas y procesar
def convert_to_list(item):
    if isinstance(item, str):  # Si el dato es una cadena, intentamos convertirlo
        try:
            item = json.loads(item.replace("'", '"'))  # Reemplazar comillas simples y cargar JSON
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
    return item  # Si ya es una lista, se devuelve tal cual

# %%
# Aplicar la función solo si es necesario
df_reviews_copy['reviews'] = df_reviews_copy['reviews'].apply(convert_to_list)

# Usar explode() para expandir los comentarios en varias filas
df_reviews_copy_expanded = df_reviews_copy.explode('reviews').reset_index(drop=True)

# Desanidar el contenido de la columna 'reviews' en columnas separadas
df_reviews_copy_final = pd.json_normalize(df_reviews_copy_expanded['reviews'])

# Unir los datos originales con la información desanidada
df_reviews_final = pd.concat([df_reviews_copy_expanded.drop(columns=['reviews']), df_reviews_copy_final], axis=1)

# %%
df_reviews_final.head()
# Out:
#              user_id                                           user_url funny  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3            js41637               http://steamcommunity.com/id/js41637
# 4            js41637               http://steamcommunity.com/id/js41637
#
#                                            helpful item_id last_edited  \
# 0                                   No ratings yet    1250
# 1                                   No ratings yet   22200
# 2                                   No ratings yet   43110
# 3  15 of 20 people (75%) found this review helpful  251610
# 4     0 of 1 people (0%) found this review helpful  227300
#
#                       posted recommend  \
# 0   Posted November 5, 2011.      True
# 1      Posted July 15, 2011.      True
# 2     Posted April 21, 2011.      True
# 3      Posted June 24, 2014.      True
# 4  Posted September 8, 2013.      True
#
#                                               review
# 0  Simple yet with great replayability. In my opi...
# 1               It's unique and worth a playthrough.
# 2  Great atmosphere. The gunplay can be a bit chu...
# 3  I know what you think when you see this title ...
# 4  For a simple (it's actually not all that simpl...

# %% [markdown]
# *En algunas columnas se aprecian valores vacíos. Convertimos todos los valores vacíos del dataframe en valores nulos para poder analizarlos posteriormente*

# %%
# Reemplazar todos los valores vacíos ('') en el df_reviews_final por NaN
df_reviews_final.replace('', np.nan, inplace=True)

# %% [markdown]
# *Se eliminan las filas duplicadas del dataframe*

# %%
# Se eliminan posibles duplicados
df_reviews_final.drop_duplicates(inplace=True)

# %%
df_reviews_final.isnull().sum()
# Out:
# user_id            0
# user_url           0
# funny          50449
# helpful           28
# item_id           28
# last_edited    52422
# posted            28
# recommend         28
# review            58
# dtype: int64

# %%
df_reviews_final.sample(5)
# Out:
#                  user_id                                           user_url  \
# 54698        bluemangreg           http://steamcommunity.com/id/bluemangreg
# 21483         tsunamitad            http://steamcommunity.com/id/tsunamitad
# 27013           checkm80              http://steamcommunity.com/id/checkm80
# 16786            piedude               http://steamcommunity.com/id/piedude
# 9786   76561198219780653  http://steamcommunity.com/profiles/76561198219...
#
#                                     funny  \
# 54698                                 NaN
# 21483  461 people found this review funny
# 27013                                 NaN
# 16786                                 NaN
# 9786                                  NaN
#
#                                                  helpful item_id last_edited  \
# 54698     2 of 2 people (100%) found this review helpful    4000         NaN
# 21483  668 of 722 people (93%) found this review helpful   72200         NaN
# 27013     1 of 1 people (100%) found this review helpful  105450         NaN
# 16786     2 of 2 people (100%) found this review helpful  255710         NaN
# 9786       3 of 6 people (50%) found this review helpful  310380         NaN
#
#                        posted recommend  \
# 54698   Posted June 24, 2014.      True
# 21483    Posted May 18, 2015.      True
# 27013         Posted June 30.      True
# 16786  Posted March 15, 2015.      True
# 9786          Posted July 22.      True
#
#                                                   review
# 54698                                                FUN
# 21483  What can I say?1 hour of gameplay to explore t...
# 27013  One of the best RTS games I've ever played. Go...
# 16786  This is one game you dont want to ignore! like...
# 9786                                              Great!

# %%
df_reviews_final[df_reviews_final['review'].isnull()].sample(5)
# Out:
#                  user_id                                           user_url  \
# 43114    STEAM0082987612       http://steamcommunity.com/id/STEAM0082987612
# 31955  76561198110176420  http://steamcommunity.com/profiles/76561198110...
# 45409        viihdavanzo           http://steamcommunity.com/id/viihdavanzo
# 32604  76561198072577997  http://steamcommunity.com/profiles/76561198072...
# 20223  76561198079342142  http://steamcommunity.com/profiles/76561198079...
#
#       funny                                         helpful item_id  \
# 43114   NaN                                  No ratings yet  224260
# 31955   NaN                                             NaN     NaN
# 45409   NaN                                  No ratings yet     730
# 32604   NaN  1 of 1 people (100%) found this review helpful     570
# 20223   NaN                                             NaN     NaN
#
#       last_edited                     posted recommend review
# 43114         NaN  Posted December 20, 2015.     False    NaN
# 31955         NaN                        NaN       NaN    NaN
# 45409         NaN  Posted September 9, 2015.      True    NaN
# 32604         NaN  Posted December 20, 2014.      True    NaN
# 20223         NaN                        NaN       NaN    NaN

# %% [markdown]
# Hallazgos:
# - df_reviews_final tiene 28 valores nulos en las columnas 'user_url', 'funny', 'last_edited', 'helpful', 'posted', 'item_id' , 'recommend' y 'review'.
# - Si el usuario tiene um item asociado, al parecer está obligado a interactuar redactando algún 'review' o recomendando o no el juego ('recommend'), y es cuando se registra la fecha en 'posted'
# - Si no existe información en estas columnas 'funny', 'last_edited', 'helpful', 'posted', 'item_id' , 'recommend' y 'review', al parecer se trataría de usuarios registrados que no tienen un item asociado, se podrían eliminar.
# - Existen columnas que podemos eliminar: 'user_url', 'funny', 'last_edited', 'helpful'
# - Se requieren hacer ajustes en los tipos de datos: 'item_id' y 'recommend'

# %% [markdown]
# Eliminación de columnas

# %%
# se eliminan columnas que no necesito: user_url, funny, last_edited, helpful 

columnas=['user_url', 'funny', 'last_edited', 'helpful']
df_reviews_final.drop(columnas,axis='columns', inplace=True)

# %%
df_reviews_final
# Out:
#                  user_id item_id                     posted recommend  \
# 0      76561197970982479    1250   Posted November 5, 2011.      True
# 1      76561197970982479   22200      Posted July 15, 2011.      True
# 2      76561197970982479   43110     Posted April 21, 2011.      True
# 3                js41637  251610      Posted June 24, 2014.      True
# 4                js41637  227300  Posted September 8, 2013.      True
# ...                  ...     ...                        ...       ...
# 59328  76561198312638244      70            Posted July 10.      True
# 59329  76561198312638244  362890             Posted July 8.      True
# 59330        LydiaMorley  273110             Posted July 3.      True
# 59331        LydiaMorley     730            Posted July 20.      True
# 59332        LydiaMorley     440             Posted July 2.      True
#
#                                                   review
# 0      Simple yet with great replayability. In my opi...
# 1                   It's unique and worth a playthrough.
# 2      Great atmosphere. The gunplay can be a bit chu...
# 3      I know what you think when you see this title ...
# 4      For a simple (it's actually not all that simpl...
# ...                                                  ...
# 59328  a must have classic from steam definitely wort...
# 59329  this game is a perfect remake of the original ...
# 59330  had so much fun plaing this and collecting res...
# 59331                                                 :D
# 59332                                     so much fun :D
#
# [58459 rows x 5 columns]

# %% [markdown]
# Tratamiento de valores nulos

# %%
# Se revisan los valores nulos en este dataframe
df_reviews_final.isnull().sum()
# Out:
# user_id       0
# item_id      28
# posted       28
# recommend    28
# review       58
# dtype: int64

# %%
# se revisan los nulos del df_reviews_final
nulos_reviews = df_reviews_final[df_reviews_final[['item_id', 'recommend', 'review']].isna().any(axis=1)]
print(nulos_reviews)
# Out:
#                    user_id item_id                      posted recommend  \
# 137                  gdxsd     NaN                         NaN       NaN
# 177      76561198094224872     NaN                         NaN       NaN
# 2559     76561198021575394     NaN                         NaN       NaN
# 3098             2ZESTY4ME     550            Posted March 11.      True
# 4619     76561198093337643     550  Posted September 19, 2014.      True
# 10080              cmuir37     NaN                         NaN       NaN
# 13767            Jaysteeny     NaN                         NaN       NaN
# 15493               ML8989     NaN                         NaN       NaN
# 15981           terencemok  218620   Posted December 30, 2014.      True
# 19184    76561198079215291     NaN                         NaN       NaN
# 20223    76561198079342142     NaN                         NaN       NaN
# 20486    76561197971285616  378041            Posted March 10.      True
# 22057               shez13  211820        Posted May 23, 2014.      True
# 22058               shez13  227320        Posted May 23, 2014.      True
# 22918             damo4lyf     620   Posted September 2, 2014.      True
# 23550       FastAsACheetah  239660   Posted September 9, 2013.      True
# 25056    76561198061996985     NaN                         NaN       NaN
# 25304    76561198098017317     730      Posted April 16, 2015.      True
# 25309    76561198072940782     570      Posted March 16, 2013.      True
# 25730    76561198081756988   17330    Posted October 29, 2013.      True
# 25731    76561198081756988  107410       Posted July 13, 2013.      True
# 26257    76561198108286351     NaN                         NaN       NaN
# 26674       CallTripleZero     NaN                         NaN       NaN
# 28315          KamuKambing     440    Posted November 7, 2013.      True
# 28444         Priceless612     NaN                         NaN       NaN
# 28452        diabolical666     NaN                         NaN       NaN
# 28975           DrScottnik     NaN                         NaN       NaN
# 31647          infidllrone     440     Posted August 14, 2015.      True
# 31955    76561198110176420     NaN                         NaN       NaN
# 32466          obviousjosh  221640       Posted June 23, 2014.      True
# 32604    76561198072577997     570   Posted December 20, 2014.      True
# 32819           jojoPL1987     NaN                         NaN       NaN
# 33785          Kylee_Kylie     NaN                         NaN       NaN
# 36007    76561198125368693   24010   Posted November 16, 2015.      True
# 37145          AlienMan180    8930  Posted September 10, 2015.      True
# 39279               _samie     NaN                         NaN       NaN
# 39357     FifthExclamation     NaN                         NaN       NaN
# 39420               sbenji     NaN                         NaN       NaN
# 40661       SpatialWheel14     NaN                         NaN       NaN
# 40980               stionk     570     Posted August 23, 2013.      True
# 41777    76561198065238937     NaN                         NaN       NaN
# 43114      STEAM0082987612  224260   Posted December 20, 2015.     False
# 43791             bajuthor     730          Posted January 13.      True
# 44384    76561198071075080     NaN                         NaN       NaN
# 45238                 CBMC  289650   Posted November 13, 2014.     False
# 45408          viihdavanzo  238960   Posted September 9, 2015.      True
# 45409          viihdavanzo     730   Posted September 9, 2015.      True
# 46707    76561198034829571     730    Posted October 30, 2014.      True
# 48199  wazzawazza80profile  313010      Posted April 11, 2015.     False
# 50718    76561198063489150     NaN                         NaN       NaN
# 52667    76561198072110631     440      Posted August 9, 2014.      True
# 53323     thecommunistbear     NaN                         NaN       NaN
# 53806    76561198077684524  230410     Posted August 28, 2014.      True
# 55425    76561198085883839     NaN                         NaN       NaN
# 56488               BNCFan  250760       Posted July 31, 2014.      True
# 56502      PLZACCEPTTHEURL  224540       Posted July 25, 2014.      True
# 57578    76561198100396147     NaN                         NaN       NaN
# 57766    76561198102423654     NaN                         NaN       NaN
#
#       review
# 137      NaN
# 177      NaN
# 2559     NaN
# 3098     NaN
# 4619     NaN
# 10080    NaN
# 13767    NaN
# 15493    NaN
# 15981    NaN
# 19184    NaN
# 20223    NaN
# 20486    NaN
# 22057    NaN
# 22058    NaN
# 22918    NaN
# 23550    NaN
# 25056    NaN
# 25304    NaN
# 25309    NaN
# 25730    NaN
# 25731    NaN
# 26257    NaN
# 26674    NaN
# 28315    NaN
# 28444    NaN
# 28452    NaN
# 28975    NaN
# 31647    NaN
# 31955    NaN
# 32466    NaN
# 32604    NaN
# 32819    NaN
# 33785    NaN
# 36007    NaN
# 37145    NaN
# 39279    NaN
# 39357    NaN
# 39420    NaN
# 40661    NaN
# 40980    NaN
# 41777    NaN
# 43114    NaN
# 43791    NaN
# 44384    NaN
# 45238    NaN
# 45408    NaN
# 45409    NaN
# 46707    NaN
# 48199    NaN
# 50718    NaN
# 52667    NaN
# 53323    NaN
# 53806    NaN
# 55425    NaN
# 56488    NaN
# 56502    NaN
# 57578    NaN
# 57766    NaN

# %%
# Estos nulos estarían relacionados, serían usuarios que no tienen interacción en la plataforma, corresponden al tipo MNAR (Missing not at random). 
# Por tanto, eliminamos los 28 filas con nulos del dataframe 
df_reviews_final = df_reviews_final.dropna()

# Mostrar el dataframe actualizado
print(df_reviews_final)
# Out:
#                  user_id item_id                     posted recommend  \
# 0      76561197970982479    1250   Posted November 5, 2011.      True
# 1      76561197970982479   22200      Posted July 15, 2011.      True
# 2      76561197970982479   43110     Posted April 21, 2011.      True
# 3                js41637  251610      Posted June 24, 2014.      True
# 4                js41637  227300  Posted September 8, 2013.      True
# ...                  ...     ...                        ...       ...
# 59328  76561198312638244      70            Posted July 10.      True
# 59329  76561198312638244  362890             Posted July 8.      True
# 59330        LydiaMorley  273110             Posted July 3.      True
# 59331        LydiaMorley     730            Posted July 20.      True
# 59332        LydiaMorley     440             Posted July 2.      True
#
#                                                   review
# 0      Simple yet with great replayability. In my opi...
# 1                   It's unique and worth a playthrough.
# 2      Great atmosphere. The gunplay can be a bit chu...
# 3      I know what you think when you see this title ...
# 4      For a simple (it's actually not all that simpl...
# ...                                                  ...
# 59328  a must have classic from steam definitely wort...
# 59329  this game is a perfect remake of the original ...
# 59330  had so much fun plaing this and collecting res...
# 59331                                                 :D
# 59332                                     so much fun :D
#
# [58401 rows x 5 columns]

# %% [markdown]
# Ajuste tipos de datos

# %%
# Finalmente se ajustan los tipos de datos para item_id y recommend

# Hacer una copia del df
df_reviews_final = df_reviews_final.copy()

# Convertir la columna 'item_id' a tipo entero, manejando nulos
df_reviews_final['item_id'] = pd.to_numeric(df_reviews_final['item_id'], errors='coerce').astype('int64')

# Convertir la columna 'recommend' a tipo booleano
df_reviews_final['recommend'] = df_reviews_final['recommend'].astype(bool)

# %%
print(df_reviews_final)
# Out:
#                  user_id  item_id                     posted  recommend  \
# 0      76561197970982479     1250   Posted November 5, 2011.       True
# 1      76561197970982479    22200      Posted July 15, 2011.       True
# 2      76561197970982479    43110     Posted April 21, 2011.       True
# 3                js41637   251610      Posted June 24, 2014.       True
# 4                js41637   227300  Posted September 8, 2013.       True
# ...                  ...      ...                        ...        ...
# 59328  76561198312638244       70            Posted July 10.       True
# 59329  76561198312638244   362890             Posted July 8.       True
# 59330        LydiaMorley   273110             Posted July 3.       True
# 59331        LydiaMorley      730            Posted July 20.       True
# 59332        LydiaMorley      440             Posted July 2.       True
#
#                                                   review
# 0      Simple yet with great replayability. In my opi...
# 1                   It's unique and worth a playthrough.
# 2      Great atmosphere. The gunplay can be a bit chu...
# 3      I know what you think when you see this title ...
# 4      For a simple (it's actually not all that simpl...
# ...                                                  ...
# 59328  a must have classic from steam definitely wort...
# 59329  this game is a perfect remake of the original ...
# 59330  had so much fun plaing this and collecting res...
# 59331                                                 :D
# 59332                                     so much fun :D
#
# [58401 rows x 5 columns]

# %%
df_reviews_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58401 entries, 0 to 59332
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    58401 non-null  object
#  1   item_id    58401 non-null  int64
#  2   posted     58401 non-null  object
#  3   recommend  58401 non-null  bool
#  4   review     58401 non-null  object
# dtypes: bool(1), int64(1), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# *Finalmente, corregimos la columna review para normalizar y eliminar todo lo que no sea texto*

# %%
col = df_reviews_final['review'].head(50)
print(col)
# Out:
# 0     Simple yet with great replayability. In my opi...
# 1                  It's unique and worth a playthrough.
# 2     Great atmosphere. The gunplay can be a bit chu...
# 3     I know what you think when you see this title ...
# 4     For a simple (it's actually not all that simpl...
# 5     Very fun little game to play when your bored o...
# 6     A suitably punishing roguelike platformer.  Wi...
# 7     "Run for fun? What the hell kind of fun is that?"
# 8     Elegant integration of gameplay, story, world ...
# 9     Random drops and random quests, with stat poin...
# 10    Fun balance of tactics and strategy.  Potentia...
# 11    Fun world builder, with plenty of option of ho...
# 12    This game... is so fun. The fight sequences ha...
# 13    Really Really Really Great Game, very good sto...
# 14    Just buy it already. Great Story, Great Multip...
# 15    It was a great game from what I played, right ...
# 16    The ending to this game is.... ♥♥♥♥♥♥♥.... Jus...
# 17    Alan wake is a really good game, the light eff...
# 18                                              Git gud
# 19    It's like Terraria, you play for 9 hours strai...
# 20                Hold shift to win, Hold CTRL to lose.
# 21    OH YES, THIS GAME IS THE BEST, THEY ADD STUFF ...
# 22                             This game is Marvellous.
# 23    It reminds me of that TV Show called "The Walk...
# 24    This game is fantastic if you are looking to D...
# 25    If you like defending dungeons then I suppose ...
# 26    You don't have to get this game. It's not like...
# 27                                        ZIKA DO BAILE
# 28                        BEST GAME IN THE BLOODY WORLD
# 29    Killed the Emperor, nobody cared and got away ...
# 30         10/10 would eat your money for hats and keys
# 31                                              love it
# 32                                               mt bom
# 33                                          É muito bom
# 34    es la rajaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...
# 35                              MAGICKA *SNORT* *SNORT*
# 36    Amazing, Non-stop action of blowing stuff to b...
# 37    Amazing, Non-stop action of blowing stuff to b...
# 38    Amazaing great, Creative and build All I'm goi...
# 39    At first, it looked to me that..."Wow, just an...
# 40    Awesome graphics, texture. Reqiures HARDCORE t...
# 41    Upside to PAYDAY 2:+ Updates are released ever...
# 42    Awesome game! It's like L4D2 and Killing Floor...
# 43    Compared to Left 4 Dead 2, this game REALLY gi...
# 44                         You won't regret playing it!
# 45                        Good Game It Was Very Fun!!!!
# 46                                            Good game
# 47                                  What a Awsome game!
# 48                               This Game Doesn't Work
# 49    I'm going to keep this somewhat short and swee...
# Name: review, dtype: object

# %%
# se define función para limpiar texto:
def clean_text(text):
    # Este codigo utiliza una expresión regular para eliminar todo lo que no sea texto y espacios en blanco
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)
    return cleaned_text

# %%
# Aplicar la función clean_text a la columna 'review'
df_reviews_final['review'] = df_reviews_final['review'].apply(clean_text)

# %%
# Verifico la limpieza realizada
columna = df_reviews_final['review'].head(50)
print(columna)
# Out:
# 0     Simple yet with great replayability In my opin...
# 1                    Its unique and worth a playthrough
# 2     Great atmosphere The gunplay can be a bit chun...
# 3     I know what you think when you see this title ...
# 4     For a simple its actually not all that simple ...
# 5     Very fun little game to play when your bored o...
# 6     A suitably punishing roguelike platformer  Win...
# 7         Run for fun What the hell kind of fun is that
# 8     Elegant integration of gameplay story world de...
# 9     Random drops and random quests with stat point...
# 10    Fun balance of tactics and strategy  Potential...
# 11    Fun world builder with plenty of option of how...
# 12    This game is so fun The fight sequences have b...
# 13    Really Really Really Great Game very good stor...
# 14    Just buy it already Great Story Great Multipla...
# 15    It was a great game from what I played right n...
# 16    The ending to this game is  Just buy it youll ...
# 17    Alan wake is a really good game the light effe...
# 18                                              Git gud
# 19    Its like Terraria you play for  hours straight...
# 20                  Hold shift to win Hold CTRL to lose
# 21    OH YES THIS GAME IS THE BEST THEY ADD STUFF LI...
# 22                              This game is Marvellous
# 23    It reminds me of that TV Show called The Walki...
# 24    This game is fantastic if you are looking to D...
# 25    If you like defending dungeons then I suppose ...
# 26    You dont have to get this game Its not like it...
# 27                                        ZIKA DO BAILE
# 28                        BEST GAME IN THE BLOODY WORLD
# 29    Killed the Emperor nobody cared and got away w...
# 30               would eat your money for hats and keys
# 31                                              love it
# 32                                               mt bom
# 33                                            muito bom
# 34    es la rajaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...
# 35                                  MAGICKA SNORT SNORT
# 36    Amazing Nonstop action of blowing stuff to bit...
# 37    Amazing Nonstop action of blowing stuff to bit...
# 38    Amazaing great Creative and build All Im going...
# 39    At first it looked to me thatWow just another ...
# 40    Awesome graphics texture Reqiures HARDCORE tea...
# 41    Upside to PAYDAY  Updates are released every f...
# 42    Awesome game Its like LD and Killing Floor but...
# 43    Compared to Left  Dead  this game REALLY gives...
# 44                           You wont regret playing it
# 45                            Good Game It Was Very Fun
# 46                                            Good game
# 47                                   What a Awsome game
# 48                                This Game Doesnt Work
# 49    Im going to keep this somewhat short and sweet...
# Name: review, dtype: object

# %% [markdown]
# ## 3. ETL de df_items

# %%
df_items.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %% [markdown]
# *Se crea copia para realizar las transformaciones*

# %%
df_items_copy = df_items.copy() # Hacemos una copia del DataFrame para hacer modificaciones del ETL

# %%
# Se aprecia fácilmente que la columna ítems está anidada. Necesitamos los datos de esta columna desanidados para cumplir con los objetivos del proyecto. Trabajaremos en desanidar estos datos y revisarlos.

# Revisamos los tipos de datos, estos están en los tipos correctos.

print(df_items_copy.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88310 entries, 0 to 88309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      88310 non-null  object
#  1   items_count  88310 non-null  int64
#  2   steam_id     88310 non-null  object
#  3   user_url     88310 non-null  object
#  4   items        88310 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB
# None

# %%
# Se revisa primer valor de la columna items
primer_dato = df_items_copy['items'].iloc[0]
print(primer_dato)
# Out:
# [{'item_id': '10', 'item_name': 'Counter-Strike', 'playtime_2weeks': 0, 'playtime_forever': 6}
#  {'item_id': '20', 'item_name': 'Team Fortress Classic', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '30', 'item_name': 'Day of Defeat', 'playtime_2weeks': 0, 'playtime_forever': 7}
#  {'item_id': '40', 'item_name': 'Deathmatch Classic', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '50', 'item_name': 'Half-Life: Opposing Force', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '60', 'item_name': 'Ricochet', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '70', 'item_name': 'Half-Life', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '130', 'item_name': 'Half-Life: Blue Shift', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '300', 'item_name': 'Day of Defeat: Source', 'playtime_2weeks': 0, 'playtime_forever': 4733}
#  {'item_id': '240', 'item_name': 'Counter-Strike: Source', 'playtime_2weeks': 0, 'playtime_forever': 1853}
#  {'item_id': '3830', 'item_name': 'Psychonauts', 'playtime_2weeks': 0, 'playtime_forever': 333}
#  {'item_id': '2630', 'item_name': 'Call of Duty 2', 'playtime_2weeks': 0, 'playtime_forever': 75}
#  {'item_id': '3900', 'item_name': "Sid Meier's Civilization IV", 'playtime_2weeks': 0, 'playtime_forever': 338}
#  {'item_id': '34440', 'item_name': "Sid Meier's Civilization IV", 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '3920', 'item_name': "Sid Meier's Pirates!", 'playtime_2weeks': 0, 'playtime_forever': 2}
#  {'item_id': '6400', 'item_name': 'Joint Task Force', 'playtime_2weeks': 0, 'playtime_forever': 286}
#  {'item_id': '6910', 'item_name': 'Deus Ex: Game of the Year Edition', 'playtime_2weeks': 0, 'playtime_forever': 2685}
#  {'item_id': '7670', 'item_name': 'BioShock', 'playtime_2weeks': 0, 'playtime_forever': 633}
#  {'item_id': '409710', 'item_name': 'BioShock Remastered', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '220', 'item_name': 'Half-Life 2', 'playtime_2weeks': 0, 'playtime_forever': 696}
#  {'item_id': '320', 'item_name': 'Half-Life 2: Deathmatch', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '340', 'item_name': 'Half-Life 2: Lost Coast', 'playtime_2weeks': 0, 'playtime_forever': 37}
#  {'item_id': '360', 'item_name': 'Half-Life Deathmatch: Source', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '380', 'item_name': 'Half-Life 2: Episode One', 'playtime_2weeks': 0, 'playtime_forever': 168}
#  {'item_id': '400', 'item_name': 'Portal', 'playtime_2weeks': 0, 'playtime_forever': 173}
#  {'item_id': '420', 'item_name': 'Half-Life 2: Episode Two', 'playtime_2weeks': 0, 'playtime_forever': 323}
#  {'item_id': '9340', 'item_name': 'Company of Heroes: Opposing Fronts', 'playtime_2weeks': 0, 'playtime_forever': 692}
#  {'item_id': '228200', 'item_name': 'Company of Heroes (New Steam Version)', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '11450', 'item_name': 'Overlord', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '7940', 'item_name': 'Call of Duty 4: Modern Warfare', 'playtime_2weeks': 0, 'playtime_forever': 1185}
#  {'item_id': '4700', 'item_name': 'Medieval II: Total War', 'playtime_2weeks': 0, 'playtime_forever': 477}
#  {'item_id': '12900', 'item_name': 'Audiosurf', 'playtime_2weeks': 0, 'playtime_forever': 115}
#  {'item_id': '13250', 'item_name': 'Unreal Gold', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '16100', 'item_name': 'Virtual Villagers: A New Home', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '15700', 'item_name': "Oddworld: Abe's Oddysee", 'playtime_2weeks': 0, 'playtime_forever': 28}
#  {'item_id': '15710', 'item_name': "Oddworld: Abe's Exoddus", 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '17330', 'item_name': 'Crysis Warhead', 'playtime_2weeks': 0, 'playtime_forever': 31}
#  {'item_id': '17340', 'item_name': 'Crysis Wars', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '22000', 'item_name': 'World of Goo', 'playtime_2weeks': 0, 'playtime_forever': 195}
#  {'item_id': '500', 'item_name': 'Left 4 Dead', 'playtime_2weeks': 0, 'playtime_forever': 513}
#  {'item_id': '4560', 'item_name': 'Company of Heroes', 'playtime_2weeks': 0, 'playtime_forever': 1061}
#  {'item_id': '17460', 'item_name': 'Mass Effect', 'playtime_2weeks': 0, 'playtime_forever': 1613}
#  {'item_id': '10500', 'item_name': 'Empire: Total War', 'playtime_2weeks': 0, 'playtime_forever': 186}
#  {'item_id': '24740', 'item_name': 'Burnout Paradise: The Ultimate Box', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '22200', 'item_name': 'Zeno Clash', 'playtime_2weeks': 0, 'playtime_forever': 271}
#  {'item_id': '26800', 'item_name': 'Braid', 'playtime_2weeks': 0, 'playtime_forever': 445}
#  {'item_id': '1250', 'item_name': 'Killing Floor', 'playtime_2weeks': 0, 'playtime_forever': 10006}
#  {'item_id': '35420', 'item_name': 'Killing Floor Mod: Defence Alliance 2', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '3590', 'item_name': 'Plants vs. Zombies: Game of the Year', 'playtime_2weeks': 0, 'playtime_forever': 4413}
#  {'item_id': '8880', 'item_name': 'Freedom Force', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '8890', 'item_name': 'Freedom Force vs. the 3rd Reich', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '23120', 'item_name': 'Droplitz', 'playtime_2weeks': 0, 'playtime_forever': 53}
#  {'item_id': '35700', 'item_name': 'Trine', 'playtime_2weeks': 0, 'playtime_forever': 199}
#  {'item_id': '10140', 'item_name': '3D Ultra Minigolf Adventures Deluxe', 'playtime_2weeks': 0, 'playtime_forever': 25}
#  {'item_id': '35010', 'item_name': 'Batman: Arkham Asylum', 'playtime_2weeks': 0, 'playtime_forever': 570}
#  {'item_id': '35140', 'item_name': 'Batman: Arkham Asylum GOTY Edition', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '29180', 'item_name': 'Osmos', 'playtime_2weeks': 0, 'playtime_forever': 940}
#  {'item_id': '15520', 'item_name': 'AaAaAA!!! - A Reckless Disregard for Gravity', 'playtime_2weeks': 0, 'playtime_forever': 110}
#  {'item_id': '32370', 'item_name': 'STAR WARS™: Knights of the Old Republic™', 'playtime_2weeks': 0, 'playtime_forever': 5}
#  {'item_id': '37700', 'item_name': 'Darkest of Days', 'playtime_2weeks': 0, 'playtime_forever': 782}
#  {'item_id': '6020', 'item_name': 'STAR WARS™ Jedi Knight: Jedi Academy™', 'playtime_2weeks': 0, 'playtime_forever': 77}
#  {'item_id': '24860', 'item_name': 'Battlefield 2', 'playtime_2weeks': 0, 'playtime_forever': 437}
#  {'item_id': '39530', 'item_name': 'Painkiller: Black Edition', 'playtime_2weeks': 0, 'playtime_forever': 503}
#  {'item_id': '550', 'item_name': 'Left 4 Dead 2', 'playtime_2weeks': 0, 'playtime_forever': 1474}
#  {'item_id': '223530', 'item_name': 'Left 4 Dead 2 Beta', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '8980', 'item_name': 'Borderlands', 'playtime_2weeks': 0, 'playtime_forever': 3061}
#  {'item_id': '41500', 'item_name': 'Torchlight', 'playtime_2weeks': 0, 'playtime_forever': 536}
#  {'item_id': '20900', 'item_name': 'The Witcher: Enhanced Edition', 'playtime_2weeks': 0, 'playtime_forever': 139}
#  {'item_id': '10180', 'item_name': 'Call of Duty: Modern Warfare 2', 'playtime_2weeks': 0, 'playtime_forever': 1886}
#  {'item_id': '10190', 'item_name': 'Call of Duty: Modern Warfare 2 - Multiplayer', 'playtime_2weeks': 0, 'playtime_forever': 1784}
#  {'item_id': '17450', 'item_name': 'Dragon Age: Origins', 'playtime_2weeks': 0, 'playtime_forever': 4431}
#  {'item_id': '3170', 'item_name': "King's Bounty: Armored Princess", 'playtime_2weeks': 0, 'playtime_forever': 1021}
#  {'item_id': '25900', 'item_name': "King's Bounty: The Legend", 'playtime_2weeks': 0, 'playtime_forever': 1389}
#  {'item_id': '31410', 'item_name': 'Zombie Driver', 'playtime_2weeks': 0, 'playtime_forever': 95}
#  {'item_id': '24980', 'item_name': 'Mass Effect 2', 'playtime_2weeks': 0, 'playtime_forever': 5001}
#  {'item_id': '8850', 'item_name': 'BioShock 2', 'playtime_2weeks': 0, 'playtime_forever': 1504}
#  {'item_id': '409720', 'item_name': 'BioShock 2 Remastered', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '46000', 'item_name': 'Bob Came in Pieces', 'playtime_2weeks': 0, 'playtime_forever': 11}
#  {'item_id': '33230', 'item_name': "Assassin's Creed II", 'playtime_2weeks': 0, 'playtime_forever': 1636}
#  {'item_id': '20820', 'item_name': 'Shatter', 'playtime_2weeks': 0, 'playtime_forever': 46}
#  {'item_id': '47700', 'item_name': 'Command and Conquer 4: Tiberian Twilight', 'playtime_2weeks': 0, 'playtime_forever': 85}
#  {'item_id': '24960', 'item_name': 'Battlefield: Bad Company 2', 'playtime_2weeks': 0, 'playtime_forever': 5716}
#  {'item_id': '43110', 'item_name': 'Metro 2033', 'playtime_2weeks': 0, 'playtime_forever': 834}
#  {'item_id': '8190', 'item_name': 'Just Cause 2', 'playtime_2weeks': 0, 'playtime_forever': 3083}
#  {'item_id': '49600', 'item_name': 'Beat Hazard', 'playtime_2weeks': 0, 'playtime_forever': 127}
#  {'item_id': '31220', 'item_name': 'Sam & Max 301: The Penal Zone', 'playtime_2weeks': 0, 'playtime_forever': 71}
#  {'item_id': '31230', 'item_name': 'Sam & Max 302: The Tomb of Sammun-Mak', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '31240', 'item_name': "Sam & Max 303: They Stole Max's Brain!", 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '31250', 'item_name': 'Sam & Max 304: Beyond the Alley of the Dolls', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '31260', 'item_name': 'Sam & Max 305: The City that Dares not Sleep', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '21090', 'item_name': 'F.E.A.R.', 'playtime_2weeks': 0, 'playtime_forever': 585}
#  {'item_id': '21110', 'item_name': 'F.E.A.R.: Extraction Point', 'playtime_2weeks': 0, 'playtime_forever': 146}
#  {'item_id': '21120', 'item_name': 'F.E.A.R.: Perseus Mandate', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '49400', 'item_name': 'Magic: The Gathering - Duels of the Planeswalkers', 'playtime_2weeks': 0, 'playtime_forever': 32}
#  {'item_id': '33910', 'item_name': 'Arma 2', 'playtime_2weeks': 0, 'playtime_forever': 3}
#  {'item_id': '33930', 'item_name': 'Arma 2: Operation Arrowhead', 'playtime_2weeks': 0, 'playtime_forever': 3}
#  {'item_id': '219540', 'item_name': 'Arma 2: Operation Arrowhead Beta (Obsolete)', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '17410', 'item_name': "Mirror's Edge", 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '205790', 'item_name': 'Dota 2 Test', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '50130', 'item_name': 'Mafia II', 'playtime_2weeks': 0, 'playtime_forever': 707}
#  {'item_id': '62100', 'item_name': 'Chime', 'playtime_2weeks': 0, 'playtime_forever': 50}
#  {'item_id': '31280', 'item_name': 'Poker Night at the Inventory', 'playtime_2weeks': 0, 'playtime_forever': 206}
#  {'item_id': '57300', 'item_name': 'Amnesia: The Dark Descent', 'playtime_2weeks': 0, 'playtime_forever': 12}
#  {'item_id': '21970', 'item_name': 'R.U.S.E', 'playtime_2weeks': 0, 'playtime_forever': 64}
#  {'item_id': '8930', 'item_name': "Sid Meier's Civilization V", 'playtime_2weeks': 0, 'playtime_forever': 10345}
#  {'item_id': '41000', 'item_name': 'Serious Sam HD: The First Encounter', 'playtime_2weeks': 0, 'playtime_forever': 369}
#  {'item_id': '41050', 'item_name': 'Serious Sam Classic: The First Encounter', 'playtime_2weeks': 0, 'playtime_forever': 76}
#  {'item_id': '41060', 'item_name': 'Serious Sam Classic: The Second Encounter', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '227780', 'item_name': 'Serious Sam Classics: Revolution', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '18040', 'item_name': 'DeathSpank', 'playtime_2weeks': 0, 'playtime_forever': 594}
#  {'item_id': '22380', 'item_name': 'Fallout: New Vegas', 'playtime_2weeks': 0, 'playtime_forever': 43}
#  {'item_id': '42700', 'item_name': 'Call of Duty: Black Ops', 'playtime_2weeks': 0, 'playtime_forever': 966}
#  {'item_id': '42710', 'item_name': 'Call of Duty: Black Ops - Multiplayer', 'playtime_2weeks': 0, 'playtime_forever': 2452}
#  {'item_id': '62000', 'item_name': 'Flight Control HD', 'playtime_2weeks': 0, 'playtime_forever': 25}
#  {'item_id': '40800', 'item_name': 'Super Meat Boy', 'playtime_2weeks': 0, 'playtime_forever': 119}
#  {'item_id': '9500', 'item_name': 'Gish', 'playtime_2weeks': 0, 'playtime_forever': 6}
#  {'item_id': '18700', 'item_name': 'And Yet It Moves', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '31270', 'item_name': 'Puzzle Agent', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '58200', 'item_name': 'Jolly Rover', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '70400', 'item_name': "Recettear: An Item Shop's Tale", 'playtime_2weeks': 0, 'playtime_forever': 537}
#  {'item_id': '41300', 'item_name': 'Altitude', 'playtime_2weeks': 0, 'playtime_forever': 50}
#  {'item_id': '41800', 'item_name': 'Gratuitous Space Battles', 'playtime_2weeks': 0, 'playtime_forever': 149}
#  {'item_id': '42500', 'item_name': 'DogFighter', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '49900', 'item_name': 'Plain Sight', 'playtime_2weeks': 0, 'playtime_forever': 23}
#  {'item_id': '55000', 'item_name': 'Flotilla', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '34330', 'item_name': 'Total War: SHOGUN 2', 'playtime_2weeks': 0, 'playtime_forever': 1538}
#  {'item_id': '63200', 'item_name': 'Monday Night Combat', 'playtime_2weeks': 0, 'playtime_forever': 573}
#  {'item_id': '99810', 'item_name': 'Bulletstorm', 'playtime_2weeks': 0, 'playtime_forever': 2}
#  {'item_id': '620', 'item_name': 'Portal 2', 'playtime_2weeks': 0, 'playtime_forever': 887}
#  {'item_id': '42910', 'item_name': 'Magicka', 'playtime_2weeks': 0, 'playtime_forever': 588}
#  {'item_id': '15500', 'item_name': 'The Wonderful End of the World', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '15540', 'item_name': '1... 2... 3... KICK IT! (Drop That Beat Like an Ugly Baby)', 'playtime_2weeks': 0, 'playtime_forever': 4}
#  {'item_id': '18500', 'item_name': 'Defense Grid: The Awakening', 'playtime_2weeks': 0, 'playtime_forever': 126}
#  {'item_id': '26500', 'item_name': 'Cogs', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '35460', 'item_name': 'The Ball', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '38700', 'item_name': 'Toki Tori', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '38720', 'item_name': 'RUSH', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '63700', 'item_name': 'BIT.TRIP BEAT', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '280', 'item_name': 'Half-Life: Source', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '20920', 'item_name': 'The Witcher 2: Assassins of Kings Enhanced Edition', 'playtime_2weeks': 0, 'playtime_forever': 1343}
#  {'item_id': '105600', 'item_name': 'Terraria', 'playtime_2weeks': 0, 'playtime_forever': 772}
#  {'item_id': '98200', 'item_name': 'Frozen Synapse', 'playtime_2weeks': 0, 'playtime_forever': 9}
#  {'item_id': '4500', 'item_name': 'S.T.A.L.K.E.R.: Shadow of Chernobyl', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '4540', 'item_name': 'Titan Quest', 'playtime_2weeks': 0, 'playtime_forever': 3}
#  {'item_id': '4550', 'item_name': 'Titan Quest: Immortal Throne', 'playtime_2weeks': 0, 'playtime_forever': 76}
#  {'item_id': '9480', 'item_name': 'Saints Row 2', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '15620', 'item_name': 'Warhammer® 40,000™: Dawn of War® II', 'playtime_2weeks': 0, 'playtime_forever': 2085}
#  {'item_id': '20500', 'item_name': 'Red Faction: Guerrilla Steam Edition', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '20570', 'item_name': 'Warhammer® 40,000™: Dawn of War® II - Chaos Rising™', 'playtime_2weeks': 0, 'playtime_forever': 69}
#  {'item_id': '50620', 'item_name': 'Darksiders', 'playtime_2weeks': 0, 'playtime_forever': 101}
#  {'item_id': '55100', 'item_name': 'Homefront', 'playtime_2weeks': 0, 'playtime_forever': 51}
#  {'item_id': '55140', 'item_name': 'MX vs. ATV Reflex', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '56400', 'item_name': 'Warhammer® 40,000™: Dawn of War® II – Retribution™', 'playtime_2weeks': 0, 'playtime_forever': 678}
#  {'item_id': '475150', 'item_name': 'Titan Quest Anniversary Edition', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '96100', 'item_name': 'Defy Gravity', 'playtime_2weeks': 0, 'playtime_forever': 9}
#  {'item_id': '35450', 'item_name': 'Rising Storm/Red Orchestra 2 Multiplayer', 'playtime_2weeks': 0, 'playtime_forever': 14194}
#  {'item_id': '236830', 'item_name': 'Red Orchestra 2: Heroes of Stalingrad - Single Player', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '72850', 'item_name': 'The Elder Scrolls V: Skyrim', 'playtime_2weeks': 0, 'playtime_forever': 2512}
#  {'item_id': '107100', 'item_name': 'Bastion', 'playtime_2weeks': 0, 'playtime_forever': 640}
#  {'item_id': '57690', 'item_name': 'Tropico 4', 'playtime_2weeks': 0, 'playtime_forever': 1815}
#  {'item_id': '91310', 'item_name': 'Dead Island', 'playtime_2weeks': 0, 'playtime_forever': 2078}
#  {'item_id': '113200', 'item_name': 'The Binding of Isaac', 'playtime_2weeks': 0, 'playtime_forever': 1494}
#  {'item_id': '65800', 'item_name': 'Dungeon Defenders', 'playtime_2weeks': 0, 'playtime_forever': 130}
#  {'item_id': '9200', 'item_name': 'RAGE', 'playtime_2weeks': 0, 'playtime_forever': 653}
#  {'item_id': '41070', 'item_name': 'Serious Sam 3: BFE', 'playtime_2weeks': 0, 'playtime_forever': 716}
#  {'item_id': '48950', 'item_name': 'Greed Corp', 'playtime_2weeks': 0, 'playtime_forever': 72}
#  {'item_id': '92800', 'item_name': 'SpaceChem', 'playtime_2weeks': 0, 'playtime_forever': 262}
#  {'item_id': '104700', 'item_name': 'Super Monday Night Combat', 'playtime_2weeks': 0, 'playtime_forever': 44}
#  {'item_id': '203770', 'item_name': 'Crusader Kings II', 'playtime_2weeks': 0, 'playtime_forever': 18}
#  {'item_id': '203810', 'item_name': 'Dear Esther', 'playtime_2weeks': 0, 'playtime_forever': 86}
#  {'item_id': '110800', 'item_name': 'L.A. Noire', 'playtime_2weeks': 0, 'playtime_forever': 1204}
#  {'item_id': '207610', 'item_name': 'The Walking Dead', 'playtime_2weeks': 0, 'playtime_forever': 798}
#  {'item_id': '98300', 'item_name': 'Toy Soldiers', 'playtime_2weeks': 0, 'playtime_forever': 110}
#  {'item_id': '50300', 'item_name': 'Spec Ops: The Line', 'playtime_2weeks': 0, 'playtime_forever': 296}
#  {'item_id': '204300', 'item_name': 'Awesomenauts', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '1700', 'item_name': 'Arx Fatalis', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '205100', 'item_name': 'Dishonored', 'playtime_2weeks': 0, 'playtime_forever': 1429}
#  {'item_id': '211120', 'item_name': 'The Political Machine', 'playtime_2weeks': 0, 'playtime_forever': 1}
#  {'item_id': '730', 'item_name': 'Counter-Strike: Global Offensive', 'playtime_2weeks': 0, 'playtime_forever': 23532}
#  {'item_id': '49520', 'item_name': 'Borderlands 2', 'playtime_2weeks': 0, 'playtime_forever': 1303}
#  {'item_id': '200260', 'item_name': 'Batman: Arkham City GOTY', 'playtime_2weeks': 0, 'playtime_forever': 100}
#  {'item_id': '212680', 'item_name': 'FTL: Faster Than Light', 'playtime_2weeks': 0, 'playtime_forever': 500}
#  {'item_id': '200710', 'item_name': 'Torchlight II', 'playtime_2weeks': 0, 'playtime_forever': 459}
#  {'item_id': '219150', 'item_name': 'Hotline Miami', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '215510', 'item_name': 'Rocketbirds: Hardboiled Chicken', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '8870', 'item_name': 'BioShock Infinite', 'playtime_2weeks': 0, 'playtime_forever': 2084}
#  {'item_id': '200510', 'item_name': 'XCOM: Enemy Unknown', 'playtime_2weeks': 0, 'playtime_forever': 3478}
#  {'item_id': '220240', 'item_name': 'Far Cry® 3', 'playtime_2weeks': 0, 'playtime_forever': 182}
#  {'item_id': '218680', 'item_name': 'Scribblenauts Unlimited', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '228280', 'item_name': "Baldur's Gate: Enhanced Edition", 'playtime_2weeks': 0, 'playtime_forever': 905}
#  {'item_id': '212070', 'item_name': 'Star Conflict', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '218230', 'item_name': 'PlanetSide 2', 'playtime_2weeks': 0, 'playtime_forever': 51}
#  {'item_id': '236390', 'item_name': 'War Thunder', 'playtime_2weeks': 0, 'playtime_forever': 50}
#  {'item_id': '3483', 'item_name': 'Peggle Extreme', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '203160', 'item_name': 'Tomb Raider', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '227080', 'item_name': 'Papo & Yo', 'playtime_2weeks': 0, 'playtime_forever': 81}
#  {'item_id': '233450', 'item_name': 'Prison Architect', 'playtime_2weeks': 0, 'playtime_forever': 24}
#  {'item_id': '43160', 'item_name': 'Metro: Last Light', 'playtime_2weeks': 0, 'playtime_forever': 712}
#  {'item_id': '219740', 'item_name': "Don't Starve", 'playtime_2weeks': 0, 'playtime_forever': 139}
#  {'item_id': '322330', 'item_name': "Don't Starve Together", 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '222730', 'item_name': 'Reus', 'playtime_2weeks': 0, 'playtime_forever': 319}
#  {'item_id': '241600', 'item_name': 'Rogue Legacy', 'playtime_2weeks': 0, 'playtime_forever': 73}
#  {'item_id': '238930', 'item_name': '7 Grand Steps, Step 1: What Ancients Begat', 'playtime_2weeks': 0, 'playtime_forever': 159}
#  {'item_id': '217140', 'item_name': 'Rise of the Triad', 'playtime_2weeks': 0, 'playtime_forever': 199}
#  {'item_id': '39140', 'item_name': 'FINAL FANTASY VII', 'playtime_2weeks': 0, 'playtime_forever': 2896}
#  {'item_id': '225080', 'item_name': 'Brothers - A Tale of Two Sons', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '239030', 'item_name': 'Papers, Please', 'playtime_2weeks': 0, 'playtime_forever': 194}
#  {'item_id': '248820', 'item_name': 'Risk of Rain', 'playtime_2weeks': 0, 'playtime_forever': 272}
#  {'item_id': '239350', 'item_name': 'Spelunky', 'playtime_2weeks': 0, 'playtime_forever': 458}
#  {'item_id': '218620', 'item_name': 'PAYDAY 2', 'playtime_2weeks': 0, 'playtime_forever': 574}
#  {'item_id': '206420', 'item_name': 'Saints Row IV', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '236850', 'item_name': 'Europa Universalis IV', 'playtime_2weeks': 0, 'playtime_forever': 89}
#  {'item_id': '47790', 'item_name': 'Medal of Honor(TM) Single Player', 'playtime_2weeks': 0, 'playtime_forever': 230}
#  {'item_id': '47830', 'item_name': 'Medal of Honor(TM) Multiplayer', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '250320', 'item_name': 'The Wolf Among Us', 'playtime_2weeks': 0, 'playtime_forever': 500}
#  {'item_id': '250900', 'item_name': 'The Binding of Isaac: Rebirth', 'playtime_2weeks': 0, 'playtime_forever': 329}
#  {'item_id': '204450', 'item_name': 'Call of Juarez Gunslinger', 'playtime_2weeks': 0, 'playtime_forever': 241}
#  {'item_id': '233270', 'item_name': 'Far Cry® 3 Blood Dragon', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '251990', 'item_name': 'Long Live The Queen', 'playtime_2weeks': 0, 'playtime_forever': 135}
#  {'item_id': '253980', 'item_name': 'Enclave', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '236450', 'item_name': 'PAC-MAN Championship Edition DX+', 'playtime_2weeks': 0, 'playtime_forever': 154}
#  {'item_id': '242050', 'item_name': "Assassin's Creed IV Black Flag", 'playtime_2weeks': 0, 'playtime_forever': 1377}
#  {'item_id': '257350', 'item_name': "Baldur's Gate II: Enhanced Edition", 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '213670', 'item_name': 'South Park™: The Stick of Truth™', 'playtime_2weeks': 0, 'playtime_forever': 121}
#  {'item_id': '238010', 'item_name': "Deus Ex: Human Revolution - Director's Cut", 'playtime_2weeks': 0, 'playtime_forever': 2176}
#  {'item_id': '245470', 'item_name': 'Democracy 3', 'playtime_2weeks': 0, 'playtime_forever': 246}
#  {'item_id': '221910', 'item_name': 'The Stanley Parable', 'playtime_2weeks': 0, 'playtime_forever': 157}
#  {'item_id': '260230', 'item_name': 'Valiant Hearts: The Great War™ / Soldats Inconnus : Mémoires de la Grande Guerre™', 'playtime_2weeks': 0, 'playtime_forever': 467}
#  {'item_id': '238430', 'item_name': 'Contagion', 'playtime_2weeks': 0, 'playtime_forever': 77}
#  {'item_id': '261030', 'item_name': 'The Walking Dead: Season Two', 'playtime_2weeks': 0, 'playtime_forever': 567}
#  {'item_id': '261570', 'item_name': 'Ori and the Blind Forest', 'playtime_2weeks': 0, 'playtime_forever': 39}
#  {'item_id': '263980', 'item_name': 'Out There Somewhere', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '39150', 'item_name': 'FINAL FANTASY VIII', 'playtime_2weeks': 0, 'playtime_forever': 15}
#  {'item_id': '230230', 'item_name': 'Divinity: Original Sin (Classic)', 'playtime_2weeks': 0, 'playtime_forever': 522}
#  {'item_id': '373420', 'item_name': 'Divinity: Original Sin Enhanced Edition', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '232790', 'item_name': 'Broken Age', 'playtime_2weeks': 0, 'playtime_forever': 216}
#  {'item_id': '237990', 'item_name': 'The Banner Saga', 'playtime_2weeks': 0, 'playtime_forever': 19}
#  {'item_id': '273620', 'item_name': 'Freespace 2', 'playtime_2weeks': 0, 'playtime_forever': 848}
#  {'item_id': '222880', 'item_name': 'Insurgency', 'playtime_2weeks': 0, 'playtime_forever': 3031}
#  {'item_id': '225840', 'item_name': 'Sven Co-op', 'playtime_2weeks': 0, 'playtime_forever': 26}
#  {'item_id': '222900', 'item_name': 'Dead Island: Epidemic', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '280220', 'item_name': 'Creeper World 3: Arc Eternal', 'playtime_2weeks': 0, 'playtime_forever': 941}
#  {'item_id': '236430', 'item_name': 'DARK SOULS™ II', 'playtime_2weeks': 0, 'playtime_forever': 592}
#  {'item_id': '201810', 'item_name': 'Wolfenstein: The New Order', 'playtime_2weeks': 0, 'playtime_forever': 599}
#  {'item_id': '294860', 'item_name': 'Valkyria Chronicles™', 'playtime_2weeks': 0, 'playtime_forever': 1735}
#  {'item_id': '295690', 'item_name': 'PARTICLE MACE', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '238460', 'item_name': 'BattleBlock Theater', 'playtime_2weeks': 0, 'playtime_forever': 407}
#  {'item_id': '237930', 'item_name': 'Transistor', 'playtime_2weeks': 0, 'playtime_forever': 154}
#  {'item_id': '301480', 'item_name': 'GEARCRACK Arena', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '303390', 'item_name': 'Dead Bits', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '306660', 'item_name': 'Ultimate General: Gettysburg', 'playtime_2weeks': 0, 'playtime_forever': 1245}
#  {'item_id': '316790', 'item_name': 'Grim Fandango Remastered', 'playtime_2weeks': 0, 'playtime_forever': 42}
#  {'item_id': '318430', 'item_name': 'Squishy the Suicidal Pig', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '241930', 'item_name': 'Middle-earth: Shadow of Mordor', 'playtime_2weeks': 0, 'playtime_forever': 889}
#  {'item_id': '328080', 'item_name': 'Retro-Pixel Castles', 'playtime_2weeks': 0, 'playtime_forever': 5}
#  {'item_id': '282070', 'item_name': 'This War of Mine', 'playtime_2weeks': 0, 'playtime_forever': 3}
#  {'item_id': '333930', 'item_name': 'Dirty Bomb', 'playtime_2weeks': 0, 'playtime_forever': 2782}
#  {'item_id': '334120', 'item_name': 'Armikrog', 'playtime_2weeks': 0, 'playtime_forever': 109}
#  {'item_id': '257510', 'item_name': 'The Talos Principle', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '319630', 'item_name': 'Life Is Strange™', 'playtime_2weeks': 0, 'playtime_forever': 37}
#  {'item_id': '346010', 'item_name': 'Besiege', 'playtime_2weeks': 0, 'playtime_forever': 464}
#  {'item_id': '255710', 'item_name': 'Cities: Skylines', 'playtime_2weeks': 0, 'playtime_forever': 246}
#  {'item_id': '232090', 'item_name': 'Killing Floor 2', 'playtime_2weeks': 0, 'playtime_forever': 6494}
#  {'item_id': '232150', 'item_name': 'Killing Floor 2 - SDK', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '377160', 'item_name': 'Fallout 4', 'playtime_2weeks': 0, 'playtime_forever': 2001}
#  {'item_id': '340170', 'item_name': 'FINAL FANTASY TYPE-0 HD', 'playtime_2weeks': 0, 'playtime_forever': 170}
#  {'item_id': '391540', 'item_name': 'Undertale', 'playtime_2weeks': 0, 'playtime_forever': 395}
#  {'item_id': '396660', 'item_name': 'Tahira: Echoes of the Astral Empire', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '337000', 'item_name': 'Deus Ex: Mankind Divided™', 'playtime_2weeks': 0, 'playtime_forever': 1159}
#  {'item_id': '368230', 'item_name': 'Kingdom: Classic', 'playtime_2weeks': 0, 'playtime_forever': 83}
#  {'item_id': '496300', 'item_name': 'Kingdom: New Lands', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '231430', 'item_name': 'Company of Heroes 2', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '289130', 'item_name': 'Endless Legend', 'playtime_2weeks': 0, 'playtime_forever': 593}
#  {'item_id': '268500', 'item_name': 'XCOM 2', 'playtime_2weeks': 0, 'playtime_forever': 1495}
#  {'item_id': '461640', 'item_name': 'Sins Of The Demon RPG', 'playtime_2weeks': 0, 'playtime_forever': 0}
#  {'item_id': '379720', 'item_name': 'DOOM', 'playtime_2weeks': 0, 'playtime_forever': 793}
#  {'item_id': '273350', 'item_name': 'Evolve Stage 2', 'playtime_2weeks': 0, 'playtime_forever': 58}]

# %%
# Aplicar la función solo si es necesario
df_items_copy['items'] = df_items_copy['items'].apply(convert_to_list)

# Usar explode() para expandir los comentarios en varias filas
df_items_copy_expand = df_items_copy.explode('items').reset_index(drop=True)

# Desanidar el contenido de la columna 'reviews' en columnas separadas
df_items_final = pd.json_normalize(df_items_copy_expand['items'])

# Unir los datos originales con la información desanidada
df_items_final = pd.concat([df_items_copy_expand.drop(columns=['items']), df_items_final], axis=1)

# %%
print(df_items_final)
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5170010  76561198329548331            7  76561198329548331
# 5170011  76561198329548331            7  76561198329548331
# 5170012  76561198329548331            7  76561198329548331
# 5170013  76561198329548331            7  76561198329548331
# 5170014  edward_tremethick            0  76561198331598578
#
#                                                   user_url item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10
# 1        http://steamcommunity.com/profiles/76561197970...      20
# 2        http://steamcommunity.com/profiles/76561197970...      30
# 3        http://steamcommunity.com/profiles/76561197970...      40
# 4        http://steamcommunity.com/profiles/76561197970...      50
# ...                                                    ...     ...
# 5170010  http://steamcommunity.com/profiles/76561198329...  373330
# 5170011  http://steamcommunity.com/profiles/76561198329...  388490
# 5170012  http://steamcommunity.com/profiles/76561198329...  521570
# 5170013  http://steamcommunity.com/profiles/76561198329...  519140
# 5170014     http://steamcommunity.com/id/edward_tremethick     NaN
#
#                              item_name  playtime_2weeks  playtime_forever
# 0                       Counter-Strike              0.0               6.0
# 1                Team Fortress Classic              0.0               0.0
# 2                        Day of Defeat              0.0               7.0
# 3                   Deathmatch Classic              0.0               0.0
# 4            Half-Life: Opposing Force              0.0               0.0
# ...                                ...              ...               ...
# 5170010                    All Is Dust              0.0               0.0
# 5170011  One Way To Die: Steam Edition              3.0               3.0
# 5170012          You Have 10 Seconds 2              4.0               4.0
# 5170013                     Minds Eyes              3.0               3.0
# 5170014                            NaN              NaN               NaN
#
# [5170015 rows x 8 columns]

# %%
print(df_items_final.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5170015 entries, 0 to 5170014
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   items_count       int64
#  2   steam_id          object
#  3   user_url          object
#  4   item_id           object
#  5   item_name         object
#  6   playtime_2weeks   float64
#  7   playtime_forever  float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 315.6+ MB
# None

# %%
# Contar el número de filas duplicadas
conteo_duplicados = df_items_final.duplicated().sum()

# Mostrar el resultado
print(f"Cantidad de filas duplicadas en df_items_final: {conteo_duplicados}")
# Out:
# Cantidad de filas duplicadas en df_items_final: 59196

# %%
# eliminamos las 59.104 filas duplicadas
df_items_final.drop_duplicates(inplace=True)
print(df_items_final)
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5170010  76561198329548331            7  76561198329548331
# 5170011  76561198329548331            7  76561198329548331
# 5170012  76561198329548331            7  76561198329548331
# 5170013  76561198329548331            7  76561198329548331
# 5170014  edward_tremethick            0  76561198331598578
#
#                                                   user_url item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10
# 1        http://steamcommunity.com/profiles/76561197970...      20
# 2        http://steamcommunity.com/profiles/76561197970...      30
# 3        http://steamcommunity.com/profiles/76561197970...      40
# 4        http://steamcommunity.com/profiles/76561197970...      50
# ...                                                    ...     ...
# 5170010  http://steamcommunity.com/profiles/76561198329...  373330
# 5170011  http://steamcommunity.com/profiles/76561198329...  388490
# 5170012  http://steamcommunity.com/profiles/76561198329...  521570
# 5170013  http://steamcommunity.com/profiles/76561198329...  519140
# 5170014     http://steamcommunity.com/id/edward_tremethick     NaN
#
#                              item_name  playtime_2weeks  playtime_forever
# 0                       Counter-Strike              0.0               6.0
# 1                Team Fortress Classic              0.0               0.0
# 2                        Day of Defeat              0.0               7.0
# 3                   Deathmatch Classic              0.0               0.0
# 4            Half-Life: Opposing Force              0.0               0.0
# ...                                ...              ...               ...
# 5170010                    All Is Dust              0.0               0.0
# 5170011  One Way To Die: Steam Edition              3.0               3.0
# 5170012          You Have 10 Seconds 2              4.0               4.0
# 5170013                     Minds Eyes              3.0               3.0
# 5170014                            NaN              NaN               NaN
#
# [5110819 rows x 8 columns]

# %% [markdown]
# Tratamiento de nulos

# %%
# revisamos los nulos de este dataframe

print(df_items_final.isnull().sum())
# Out:
# user_id                 0
# items_count             0
# steam_id                0
# user_url                0
# item_id             16714
# item_name           16714
# playtime_2weeks     16714
# playtime_forever    16714
# dtype: int64

# %%
# Filtrar las filas donde hay valores nulos para las columnas 'item_id', 'item_name', 'playtime_forever'
nulos_items = df_items_final[df_items_final[['item_id', 'item_name', 'playtime_forever']].isna().any(axis=1)]

# Mostrar el resultado
nulos_items
# Out:
#                          user_id  items_count           steam_id  \
# 3733                      Wackky            0  76561198039117046
# 3849           76561198079601835            0  76561198079601835
# 6019                    hellom8o            0  76561198117222320
# 6523         starkillershadow553            0  76561198059648579
# 7237                  darkenkane            0  76561198058876001
# ...                          ...          ...                ...
# 5169470        76561198316380182            0  76561198316380182
# 5169471        76561198316970597            0  76561198316970597
# 5169472        76561198318100691            0  76561198318100691
# 5170006  XxLaughingJackClown77xX            0  76561198328759259
# 5170014        edward_tremethick            0  76561198331598578
#
#                                                   user_url item_id item_name  \
# 3733                   http://steamcommunity.com/id/Wackky     NaN       NaN
# 3849     http://steamcommunity.com/profiles/76561198079...     NaN       NaN
# 6019                 http://steamcommunity.com/id/hellom8o     NaN       NaN
# 6523      http://steamcommunity.com/id/starkillershadow553     NaN       NaN
# 7237               http://steamcommunity.com/id/darkenkane     NaN       NaN
# ...                                                    ...     ...       ...
# 5169470  http://steamcommunity.com/profiles/76561198316...     NaN       NaN
# 5169471  http://steamcommunity.com/profiles/76561198316...     NaN       NaN
# 5169472  http://steamcommunity.com/profiles/76561198318...     NaN       NaN
# 5170006  http://steamcommunity.com/id/XxLaughingJackClo...     NaN       NaN
# 5170014     http://steamcommunity.com/id/edward_tremethick     NaN       NaN
#
#          playtime_2weeks  playtime_forever
# 3733                 NaN               NaN
# 3849                 NaN               NaN
# 6019                 NaN               NaN
# 6523                 NaN               NaN
# 7237                 NaN               NaN
# ...                  ...               ...
# 5169470              NaN               NaN
# 5169471              NaN               NaN
# 5169472              NaN               NaN
# 5170006              NaN               NaN
# 5170014              NaN               NaN
#
# [16714 rows x 8 columns]

# %% [markdown]
# Estos valores faltantes serían del tipo MNAR (Missing not at random), ya que se trataría sólo de personas registradas en la plataforma sin interacción.
#
# Esto se intuye dado que si items_count es igual a 0, no pueden existir datos de item_id, item_name y playtime_forever.

# %%
# Verificamos esta hipotesis chequeando si items_count tiene un valor igual a 0 en todas las filas de nulos

conteo_nulos_items = nulos_items['items_count'].value_counts()
print(conteo_nulos_items)
# Out:
# items_count
# 0    16714
# Name: count, dtype: int64

# %% [markdown]
# Como vemos, sólo existe el 0 como valor en la columna items_count, en este caso, serían usuarios sin interacción con la plataforma. Procedo a eliminar los nulos de df_items_final aplicando el método dropna()

# %%
# Eliminamos los nulos del dataframe 
df_items_final = df_items_final.dropna()

# Mostrar el dataframe actualizado
print(df_items_final.isnull().sum())
# Out:
# user_id             0
# items_count         0
# steam_id            0
# user_url            0
# item_id             0
# item_name           0
# playtime_2weeks     0
# playtime_forever    0
# dtype: int64

# %% [markdown]
# Ajuste tipos de datos

# %%
df_items_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5094105 entries, 0 to 5170013
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   items_count       int64
#  2   steam_id          object
#  3   user_url          object
#  4   item_id           object
#  5   item_name         object
#  6   playtime_2weeks   float64
#  7   playtime_forever  float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 349.8+ MB

# %% [markdown]
# Todos los tipos de datos están correctos, excepto para item_id. Revisamos esta columna antes de proceder.

# %%
df_items_final['item_id'].sample(20)
# Out:
# 2605183     91600
# 3026939    226720
# 3823232       620
# 3857652      9200
# 4351259    261640
# 2910306    239220
# 3705204    205230
# 3286303        70
# 2650993    224760
# 709437      31190
# 5056514    299820
# 3038806    105600
# 4241496    206440
# 317129      15130
# 4172391    204630
# 5166935    304050
# 4730198       730
# 601515      31280
# 4372924    221260
# 2469423    390880
# Name: item_id, dtype: object

# %% [markdown]
# Los valores parecieran que son todos numéricos, por tanto realizamos el casteo.

# %%
# Hacer una copia del df
df_items_final = df_items_final.copy()

# Convertir la columna 'item_id' a tipo entero, manejando nulos
df_items_final['item_id'] = pd.to_numeric(df_items_final['item_id']).astype('int64')

# %%
# Verificamos el cambio
df_items_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5094105 entries, 0 to 5170013
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   items_count       int64
#  2   steam_id          object
#  3   user_url          object
#  4   item_id           int64
#  5   item_name         object
#  6   playtime_2weeks   float64
#  7   playtime_forever  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 349.8+ MB

# %% [markdown]
# Eliminación de columnas

# %%
# Eliminamos columnas que no necesitaremos: playtime_2weeks
col=['playtime_2weeks', 'user_url', 'steam_id']

df_items_final.drop(col,axis='columns', inplace=True)

# %%
# Visualizamos dataset
df_items_final
# Out:
#                    user_id  items_count  item_id  \
# 0        76561197970982479          277       10
# 1        76561197970982479          277       20
# 2        76561197970982479          277       30
# 3        76561197970982479          277       40
# 4        76561197970982479          277       50
# ...                    ...          ...      ...
# 5170009  76561198329548331            7   346330
# 5170010  76561198329548331            7   373330
# 5170011  76561198329548331            7   388490
# 5170012  76561198329548331            7   521570
# 5170013  76561198329548331            7   519140
#
#                              item_name  playtime_forever
# 0                       Counter-Strike               6.0
# 1                Team Fortress Classic               0.0
# 2                        Day of Defeat               7.0
# 3                   Deathmatch Classic               0.0
# 4            Half-Life: Opposing Force               0.0
# ...                                ...               ...
# 5170009                   BrainBread 2               0.0
# 5170010                    All Is Dust               0.0
# 5170011  One Way To Die: Steam Edition               3.0
# 5170012          You Have 10 Seconds 2               4.0
# 5170013                     Minds Eyes               3.0
#
# [5094105 rows x 5 columns]

# %%
df_items_final.isnull().sum()
# Out:
# user_id             0
# items_count         0
# item_id             0
# item_name           0
# playtime_forever    0
# dtype: int64

# %% [markdown]
# *Finalmente, limpiamos columna 'item_name' de caracteres especiales y símbolos*

# %%
def clean_text(text):
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)
    return cleaned_text


# Aplicó la función a columna item_name
df_items_final['item_name'] = df_items_final['item_name'].apply(clean_text)

# %% [markdown]
# ## 3. ETL de df_games

# %%
print(df_games)
# Out:
#               publisher                                 genres  \
# 0                  None                                   None
# 1                  None                                   None
# 2                  None                                   None
# 3                  None                                   None
# 4                  None                                   None
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444             None                                   None
#
#                         app_name                     title  \
# 0                           None                      None
# 1                           None                      None
# 2                           None                      None
# 3                           None                      None
# 4                           None                      None
# ...                          ...                       ...
# 120440            Colony On Mars            Colony On Mars
# 120441  LOGistICAL: South Africa  LOGistICAL: South Africa
# 120442             Russian Roads             Russian Roads
# 120443       EXIT 2 - Directions       EXIT 2 - Directions
# 120444               Maze Run VR                      None
#
#                                                       url release_date  \
# 0                                                    None         None
# 1                                                    None         None
# 2                                                    None         None
# 3                                                    None         None
# 4                                                    None         None
# ...                                                   ...          ...
# 120440  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 120441  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 120442  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 120443  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 120444  http://store.steampowered.com/app/681550/Maze_...         None
#
#                                                      tags  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 120444  [Early Access, Adventure, Indie, Action, Simul...
#
#                                               reviews_url  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 120440  http://steamcommunity.com/app/773640/reviews/?...
# 120441  http://steamcommunity.com/app/733530/reviews/?...
# 120442  http://steamcommunity.com/app/610660/reviews/?...
# 120443  http://steamcommunity.com/app/658870/reviews/?...
# 120444  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                     specs price  early_access  \
# 0                                                    None  None           NaN
# 1                                                    None  None           NaN
# 2                                                    None  None           NaN
# 3                                                    None  None           NaN
# 4                                                    None  None           NaN
# ...                                                   ...   ...           ...
# 120440                [Single-player, Steam Achievements]  1.99           0.0
# 120441  [Single-player, Steam Achievements, Steam Clou...  4.99           0.0
# 120442  [Single-player, Steam Achievements, Steam Trad...  1.99           0.0
# 120443   [Single-player, Steam Achievements, Steam Cloud]  4.99           0.0
# 120444  [Single-player, Stats, Steam Leaderboards, HTC...  4.99           1.0
#
#               id                 developer
# 0            NaN                      None
# 1            NaN                      None
# 2            NaN                      None
# 3            NaN                      None
# 4            NaN                      None
# ...          ...                       ...
# 120440  773640.0        Nikita "Ghost_RUS"
# 120441  733530.0                    Sacada
# 120442  610660.0  Laush Dmitriy Sergeevich
# 120443  658870.0             xropi,stev3ns
# 120444  681550.0                      None
#
# [120445 rows x 13 columns]

# %% [markdown]
# Se crea una copia del DF donde se realizarán todas las transformaciones.

# %%
df_games_clean = df_games.copy() # Hacemos una copia del DataFrame para hacer modificaciones del ETL

# %%
# Revisamos la cantidad de no- nulos
df_games_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  float64
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 11.9+ MB

# %% [markdown]
# # Eliminación filas completamente Nulas

# %% [markdown]
# En esta parte, se descartarán las filas nulas que a simple vista podemos ver en este dataframe.

# %% [markdown]
# Primero hacemos una copia del DataFrame para hacer modificaciones del ETL

# %%
df_games_clean = df_games.copy() # Hacemos una copia del DataFrame para hacer modificaciones del ETL

# %%
# Definimos el número mínimo de valores no-None que una fila debe tener
thresh_value = 3  # Esto significa que las filas deben tener al menos 3 valores no-None para no ser eliminadas

# Eliminar filas que tienen más valores None que el umbral permitido
df_games_clean = df_games_clean.dropna(thresh=thresh_value)

# %%
df_games_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32135 entries, 88310 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  float64
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 3.4+ MB

# %%
# Mostrar el DataFrame limpio
df_games_clean.sample(5)
# Out:
#                    publisher                        genres  \
# 110771                  None                    [Strategy]
# 111128         SecureMix LLC                   [Utilities]
# 97375                   None          [Casual, Simulation]
# 99912                   None  [Adventure, Indie, Strategy]
# 104213  Pooandplay, Jogaloca       [Action, Casual, Indie]
#
#                                                  app_name  \
# 110771                               Star Realms - Heroes
# 111128                                    GlassWire Basic
# 97375   Rocksmith® 2014 Edition – Remastered – Avril L...
# 99912                     Card City Nights 2 - Soundtrack
# 104213                                 Toys Gun Fire Boom
#
#                                                     title  \
# 110771                               Star Realms - Heroes
# 111128                                    GlassWire Basic
# 97375   Rocksmith® 2014 Edition – Remastered – Avril L...
# 99912                     Card City Nights 2 - Soundtrack
# 104213                                 Toys Gun Fire Boom
#
#                                                       url release_date  \
# 110771  http://store.steampowered.com/app/499550/Star_...   2016-07-06
# 111128  http://store.steampowered.com/app/384530/Glass...   2016-06-07
# 97375   http://store.steampowered.com/app/509737/Rocks...   2017-03-07
# 99912   http://store.steampowered.com/app/719710/Card_...   2017-09-21
# 104213  http://store.steampowered.com/app/674900/Toys_...   2017-09-03
#
#                                 tags  \
# 110771                    [Strategy]
# 111128                   [Utilities]
# 97375           [Casual, Simulation]
# 99912   [Strategy, Adventure, Indie]
# 104213       [Action, Casual, Indie]
#
#                                               reviews_url  \
# 110771  http://steamcommunity.com/app/499550/reviews/?...
# 111128  http://steamcommunity.com/app/384530/reviews/?...
# 97375   http://steamcommunity.com/app/509737/reviews/?...
# 99912   http://steamcommunity.com/app/719710/reviews/?...
# 104213  http://steamcommunity.com/app/674900/reviews/?...
#
#                                                     specs price  early_access  \
# 110771  [Single-player, Multi-player, Cross-Platform M...  1.99           0.0
# 111128                             [Downloadable Content]  49.0           0.0
# 97375   [Single-player, Shared/Split Screen, Downloada...  2.99           0.0
# 99912   [Single-player, Online Multi-Player, Downloada...  3.99           0.0
# 104213  [Single-player, Multi-player, Co-op, Steam Ach...  5.99           0.0
#
#               id                developer
# 110771  499550.0       White Wizard Games
# 111128  384530.0            SecureMix LLC
# 97375   509737.0  Ubisoft - San Francisco
# 99912   719710.0                 Ludosity
# 104213  674900.0               Pooandplay

# %% [markdown]
# # Tratamiento de valores faltantes

# %% [markdown]
# En esta sección analizaremos las posibles estrategias para llenar los campos faltantes en cada columna.

# %%
# Primero definimos una función para identificar valores faltantes

def missing_values_table(df):

    '''Función que devuelve los valores faltantes de cada columna de un dataset, y cuál es su porcentaje respecto del
    total de valores de cada columna'''
    
    miss_val = df.isnull().sum()
    miss_val_percent = 100 * df.isnull().sum() / len(df)
    
    # tabla con los resultados
    miss_val_table = pd.concat([miss_val, miss_val_percent], axis = 1)
    
    # Renombramos las columnas
    miss_val_table_ren_columns = miss_val_table.rename(columns = {0: 'Valores Faltantes', 1:
                                                               '% de Valores Totales'})
    # Ordenamos la tabla por el porcentaje en orden descendente
    miss_val_table_ren_columns = miss_val_table_ren_columns[
        miss_val_table_ren_columns.iloc[:,1] != 0].sort_values('% de Valores Totales',
                                                             ascending = False).round(1)
    
    # Imprimir el resumen de la información
    print('El dataframe seleccionado tiene '+ str(df.shape[1]) + ' columnas.\n'
         'Hay ' + str(miss_val_table_ren_columns.shape[0]) + 
         ' columnas que tienen valores faltantes.')
    
    # Devuelve el dataframe con informacion faltante
    return miss_val_table_ren_columns

# %%
# Usamos función recién creada
miss_df_games = missing_values_table(df_games_clean)
print('\nValores faltantes del dataset df_steam_clean:')
print(miss_df_games)
# Out:
# El dataframe seleccionado tiene 13 columnas.
# Hay 11 columnas que tienen valores faltantes.
#
# Valores faltantes del dataset df_steam_clean:
#               Valores Faltantes  % de Valores Totales
# publisher                  8052                  25.1
# developer                  3299                  10.3
# genres                     3283                  10.2
# release_date               2067                   6.4
# title                      2050                   6.4
# price                      1377                   4.3
# specs                       670                   2.1
# tags                        163                   0.5
# app_name                      2                   0.0
# reviews_url                   2                   0.0
# id                            2                   0.0

# %% [markdown]
# Hallazgos:
# - Las columnas app_name y title son iguales al parecer, pero se podrían rellenar algunos valores faltantes en alguna de estas columnas, y eliminar una.
# - Las columnas genre y tag comparten información sobre el género del juego. Se completará genre, que es una columna que necesitamos, con los valores de tags (que posee sólo 163 nulos), y se eliminará tags.
# - Se deberá buscar una estrategia para el tratamiento de los nombres de ítem escritos en alfabeto distinto al latino.
# - Los valores faltantes en columnas clave son altos: publisher, developer, genres. Se evaluará con mayor información si eliminamos algunas columnas luego de hacer algunas transformaciones.
# - Algunos nombres de publisher coinciden con developer, pero en la mayor parte de los casos no lo hacen.
# - url contiene el nombre (title) del juego, se puede usar para completar la columna title si es necesraio.
# - Columnas candidatas a eliminar: app_name o title (fusionar), url, tags, reviews_url, specs y early_access.

# %%
# revisamos columnas app_name y title, qué tantos valores coinciden
son_iguales = df_games_clean['app_name'].equals(df_games_clean['title'])
conteo_iguales = (df_games_clean['app_name'] == df_games_clean['title']).sum()

# Mostrar el resultado
print(f"Cantidad de filas donde 'app_name' y 'title' son iguales: {conteo_iguales}")

# Contar cuántos valores son diferentes
conteo_diferentes = (df_games_clean['app_name'] != df_games_clean['title']).sum()
print(f"Cantidad de filas donde 'app_name' y 'title' son diferentes: {conteo_diferentes}")


if not son_iguales:
    diferencias = df_games_clean[df_games_clean['app_name'] != df_games_clean['title']]
    
print(f'Conteo nulos:', diferencias.isnull().sum())
# Out:
# Cantidad de filas donde 'app_name' y 'title' son iguales: 29530
# Cantidad de filas donde 'app_name' y 'title' son diferentes: 2605
# Conteo nulos: publisher       2231
# genres          2063
# app_name           2
# title           2050
# url                0
# release_date    2049
# tags               3
# reviews_url        1
# specs             19
# price            127
# early_access       0
# id                 1
# developer       2060
# dtype: int64

# %% [markdown]
# La gran parte de las diferencias entre app_name y title corresponde a valores nulos que posee title. 'App_name posee un solo nulo, nos quedamos con esta columna y eliminamos title.

# %%
# Filtrar las filas donde 'title' no sea nulo y sea diferente de 'app_name'
diferentes = df_games_clean[(df_games_clean['title'].notna()) & (df_games_clean['title'] != df_games_clean['app_name'])]

# Mostrar el resultado
diferentes[['app_name', 'title']]
# Out:
#                                              app_name  \
# 88390                    Sam & Max 101: Culture Shock
# 88393                Sam & Max 102: Situation: Comedy
# 88419                  Command & Conquer: Red Alert 3
# 88492      Heroes of Might & Magic V: Hammers of Fate
# 88494   Heroes of Might & Magic V: Tribes of the East
# ...                                               ...
# 120181                     Sam & Max 105: Reality 2.0
# 120182           Sam & Max 104: Abe Lincoln Must Die!
# 120183         Sam & Max 106: Bright Side of the Moon
# 120208           Making History: The Calm & the Storm
# 120362                  Dark Messiah of Might & Magic
#
#                                                     title
# 88390                    Sam &amp; Max 101: Culture Shock
# 88393                Sam &amp; Max 102: Situation: Comedy
# 88419                  Command &amp; Conquer: Red Alert 3
# 88492      Heroes of Might &amp; Magic V: Hammers of Fate
# 88494   Heroes of Might &amp; Magic V: Tribes of the East
# ...                                                   ...
# 120181                     Sam &amp; Max 105: Reality 2.0
# 120182           Sam &amp; Max 104: Abe Lincoln Must Die!
# 120183         Sam &amp; Max 106: Bright Side of the Moon
# 120208           Making History: The Calm &amp; the Storm
# 120362                  Dark Messiah of Might &amp; Magic
#
# [555 rows x 2 columns]

# %% [markdown]
# Las diferencias al parecer sería porque en title no reconoce el ampersand. Lo corregimos y evaluamos.

# %%
# Reemplazar '&amp;' por '&' en la columna 'title'
df_games_clean['title'] = df_games_clean['title'].str.replace('&amp;', '&', regex=False)

# Mostrar los primeros registros para verificar el cambio
print(df_games_clean[['app_name', 'title']].head())
# Out:
#                       app_name                    title
# 88310      Lost Summoner Kitty      Lost Summoner Kitty
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313                  弹炸人2222                  弹炸人2222
# 88314            Log Challenge                     None

# %% [markdown]
# Evaluamos el conteo de nulos nuevamente

# %%
# revisamos columnas app_name y title, qué tantos valores coinciden
son_iguales = df_games_clean['app_name'].equals(df_games_clean['title'])
conteo_iguales = (df_games_clean['app_name'] == df_games_clean['title']).sum()

# Mostrar el resultado
print(f"Cantidad de filas donde 'app_name' y 'title' son iguales: {conteo_iguales}")

# Contar cuántos valores son diferentes
conteo_diferentes = (df_games_clean['app_name'] != df_games_clean['title']).sum()
print(f"Cantidad de filas donde 'app_name' y 'title' son diferentes: {conteo_diferentes}")


if not son_iguales:
    diferencias = df_games_clean[df_games_clean['app_name'] != df_games_clean['title']]
    
print(f'Conteo nulos:', diferencias.isnull().sum())
# Out:
# Cantidad de filas donde 'app_name' y 'title' son iguales: 30080
# Cantidad de filas donde 'app_name' y 'title' son diferentes: 2055
# Conteo nulos: publisher       2050
# genres          2049
# app_name           2
# title           2050
# url                0
# release_date    2049
# tags               2
# reviews_url        1
# specs              1
# price            117
# early_access       0
# id                 1
# developer       2050
# dtype: int64

# %%
# Filtrar nuevamente las filas donde 'title' no sea nulo y sea diferente de 'app_name'
diferentes2 = df_games_clean[(df_games_clean['title'].notna()) & (df_games_clean['title'] != df_games_clean['app_name'])]

# Mostrar el resultado
diferentes2[['app_name', 'title']]
# Out:
#                     app_name                                 title
# 88541   Guild Wars Nightfall                 Guild Wars Nightfall®
# 88542             Guild Wars  Guild Wars® Game of the Year Edition
# 88543    Guild Wars Factions                  Guild Wars Factions®
# 99323             >observer_                         &gt;observer_
# 106020       >//:System.Hack                    &gt;//:System.Hack

# %% [markdown]
# El resultado anterior nos muestra las diferencias que aún persisten entre app_name y title, debido a caracteres especiales. Podemos concluir que title y app_name son prácticamente iguales. Nos quedamos con app_name y eliminamos title.

# %%
# Eliminar la columna 'title' , además de las columnas 'url', 'user_url', 'early_access', que no necesitaremos
col = ['title', 'url', 'specs', 'reviews_url', 'early_access']
df_games_clean = df_games_clean.drop(columns=col)

# %%
# Mostrar el DataFrame actualizado
print(df_games_clean)
# Out:
#                publisher                                             genres  \
# 88310          Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311   Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312       Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313               彼岸领域                        [Action, Adventure, Casual]
# 88314               None                                               None
# ...                  ...                                                ...
# 120440   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 120441            Sacada                          [Casual, Indie, Strategy]
# 120442      Laush Studio                        [Indie, Racing, Simulation]
# 120443          SIXNAILS                                    [Casual, Indie]
# 120444              None                                               None
#
#                         app_name release_date  \
# 88310        Lost Summoner Kitty   2018-01-04
# 88311                  Ironbound   2018-01-04
# 88312    Real Pool 3D - Poolians   2017-07-24
# 88313                    弹炸人2222   2017-12-07
# 88314              Log Challenge         None
# ...                          ...          ...
# 120440            Colony On Mars   2018-01-04
# 120441  LOGistICAL: South Africa   2018-01-04
# 120442             Russian Roads   2018-01-04
# 120443       EXIT 2 - Directions   2017-09-02
# 120444               Maze Run VR         None
#
#                                                      tags         price  \
# 88310       [Strategy, Action, Indie, Casual, Simulation]          4.99
# 88311   [Free to Play, Strategy, Indie, RPG, Card Game...  Free To Play
# 88312   [Free to Play, Simulation, Sports, Casual, Ind...  Free to Play
# 88313                         [Action, Adventure, Casual]          0.99
# 88314                     [Action, Indie, Casual, Sports]          2.99
# ...                                                   ...           ...
# 120440              [Strategy, Indie, Casual, Simulation]          1.99
# 120441                          [Strategy, Indie, Casual]          4.99
# 120442                        [Indie, Simulation, Racing]          1.99
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...          4.99
# 120444  [Early Access, Adventure, Indie, Action, Simul...          4.99
#
#               id                 developer
# 88310   761140.0                 Kotoshiro
# 88311   643980.0          Secret Level SRL
# 88312   670290.0              Poolians.com
# 88313   767400.0                      彼岸领域
# 88314   773570.0                      None
# ...          ...                       ...
# 120440  773640.0        Nikita "Ghost_RUS"
# 120441  733530.0                    Sacada
# 120442  610660.0  Laush Dmitriy Sergeevich
# 120443  658870.0             xropi,stev3ns
# 120444  681550.0                      None
#
# [32135 rows x 8 columns]

# %% [markdown]
# Análisis columna publisher

# %%
# Se filtran los valores nulos de la columna publisher para observar

filtro_publisher= df_games_clean[df_games_clean['publisher'].isna()]

# %%
# Se selecciona una muestra para revisar patrones en los datos
filtro_publisher.sample(10)
# Out:
#        publisher                                       genres  \
# 114648      None  [Adventure, Casual, Indie, RPG, Simulation]
# 97185       None                                         None
# 95924       None                      [Action, Casual, Indie]
# 90810       None                         [Casual, Simulation]
# 117232      None                         [Casual, Simulation]
# 96005       None                                         None
# 94198       None                                         None
# 114450      None                      [Action, Casual, Indie]
# 106393      None                                         None
# 110059      None                                         None
#
#                                            app_name release_date  \
# 114648                       FREE Soccer Theme Pack   2015-06-17
# 97185       Andy Kaufman: My Breakfast With Blassie   1983-11-01
# 95924                          Project Starship OST   2016-10-18
# 90810   Rocksmith® 2014 – Biffy Clyro - “Mountains”   2014-08-05
# 117232     Rocksmith® 2014 – Sum 41 - “In Too Deep”   2014-06-03
# 96005                                  Island Queen   2012-05-04
# 94198                                         Saw 3   2007-01-23
# 114450                                  TeraBlaster   2015-07-10
# 106393                               Drone Fighters         None
# 110059                                       Piñata         None
#
#                                                      tags         price  \
# 114648        [Adventure, RPG, Indie, Casual, Simulation]          None
# 97185                                             [Movie]          2.99
# 95924                             [Action, Indie, Casual]          0.99
# 90810                                [Casual, Simulation]          2.99
# 117232                               [Casual, Simulation]          2.99
# 96005                              [Short, Comedy, Drama]          1.99
# 94198           [Movie, Mystery, Crime, Horror, Thriller]          3.99
# 114450       [Indie, Casual, Action, Retro, Shoot 'Em Up]  Free to Play
# 106393  [Early Access, Action, Indie, Simulation, Spor...          6.99
# 110059      [Free to Play, Indie, Casual, Simulation, VR]  Free To Play
#
#               id                developer
# 114648  380760.0       Stolen Couch Games
# 97185   596010.0                     None
# 95924   541830.0               xXarabonXx
# 90810   294975.0  Ubisoft - San Francisco
# 117232  294925.0  Ubisoft - San Francisco
# 96005   413250.0                     None
# 94198   421450.0                     None
# 114450  384150.0        Black Shell Games
# 106393  612600.0                     None
# 110059  477800.0                     None

# %% [markdown]
# Revisar en qué coinciden publisher y developer

# %%
# Contar cuántas veces ambas columnas son nulas
ambos_nulos = df_games_clean[df_games_clean['publisher'].isnull() & df_games_clean['developer'].isnull()].shape[0]
print(f"Cantidad de filas donde 'publisher' y 'developer' son nulos: {ambos_nulos}")

# Contar cuántas veces sólo 'publisher' es nulo y 'developer' no lo es
publisher_nulo = df_games_clean[df_games_clean['publisher'].isnull() & df_games_clean['developer'].notnull()].shape[0]
print(f"Cantidad de filas donde 'publisher' es nulo y 'developer' no es nulo: {publisher_nulo}")

# Contar cuántas veces sólo 'developer' es nulo y 'publisher' no lo es
developer_nulo = df_games_clean[df_games_clean['developer'].isnull() & df_games_clean['publisher'].notnull()].shape[0]
print(f"Cantidad de filas donde 'developer' es nulo y 'publisher' no es nulo: {developer_nulo}")

coinciden_no_nulos = df_games_clean[(df_games_clean['publisher'] == df_games_clean['developer']) & df_games_clean['publisher'].notnull()].shape[0]
print(f"Cantidad de filas donde 'publisher' y 'developer' son iguales (excluyendo nulos): {coinciden_no_nulos}")

diferentes_no_nulos = df_games_clean[(df_games_clean['publisher'] != df_games_clean['developer']) & df_games_clean['publisher'].notnull() & df_games_clean['developer'].notnull()].shape[0]
print(f"Cantidad de filas donde 'publisher' y 'developer' son diferentes y ambos no son nulos: {diferentes_no_nulos}")
# Out:
# Cantidad de filas donde 'publisher' y 'developer' son nulos: 3234
# Cantidad de filas donde 'publisher' es nulo y 'developer' no es nulo: 4818
# Cantidad de filas donde 'developer' es nulo y 'publisher' no es nulo: 65
# Cantidad de filas donde 'publisher' y 'developer' son iguales (excluyendo nulos): 12432
# Cantidad de filas donde 'publisher' y 'developer' son diferentes y ambos no son nulos: 11586

# %%
# Filtrar las filas donde tanto 'publisher' como 'developer' son nulos
filtro_nulos = df_games_clean[(df_games_clean['publisher'].isnull()) & (df_games_clean['developer'].isnull())]

filtro_nulos.head()
# Out:
#       publisher genres              app_name release_date  \
# 88314      None   None         Log Challenge         None
# 88321      None   None  Icarus Six Sixty Six         None
# 88329      None   None         After Life VR         None
# 88330      None   None            Kitty Hawk         None
# 88332      None   None            Mortars VR         None
#
#                                                     tags price        id  \
# 88314                    [Action, Indie, Casual, Sports]  2.99  773570.0
# 88321                                           [Casual]  Free  724910.0
# 88329                          [Early Access, Indie, VR]  4.99  772590.0
# 88330   [Early Access, Action, Adventure, Indie, Casual]  2.99  640250.0
# 88332  [Early Access, Strategy, Action, Indie, Casual...  0.99  711440.0
#
#       developer
# 88314      None
# 88321      None
# 88329      None
# 88330      None
# 88332      None

# %% [markdown]
# *Excluyendo a los valores nulos, existen 12.432 datos que son iguales entre publisher y developer. Nos centramos en revisar el último resultado, 'Cantidad de filas donde 'publisher' y 'developer' son diferentes y ambos no son nulos: 11586' para ver qué tanto difieren estos datos entre si.*

# %%
# Filtrar las filas donde 'publisher' y 'developer' son distintos y ambos no son nulos
diferentes_no_nulos = df_games_clean[(df_games_clean['publisher'] != df_games_clean['developer']) & df_games_clean['publisher'].notnull() & df_games_clean['developer'].notnull()]

# %%
# Mostrar el DataFrame filtrado
diferentes_no_nulos[['publisher', 'developer']].sample(10)
# Out:
#                   publisher                                       developer
# 113877  Dagestan Technology                                    Hipix Studio
# 102599          ArcaneRaise                                    Arcane Raise
# 97605       NewRealityGames                                        Lapovich
# 106983               Degica                                       NIVLACART
# 108789       Big Fish Games                                  Elephant Games
# 102026       Refproto Games                                        Mianwotu
# 118241             2K Games                                        2K Marin
# 99693          Laush Studio                        Laush Dmitriy Sergeevich
# 108499          rokapublish                                       bumblebee
# 91371             505 Games  Lion Game Lion,OVERKILL - a Starbreeze Studio.

# %% [markdown]
# Al revisar las sucesivas muestras de datos, estos 11.586 datos difieren en casi su totalidad, por tanto no podemos generalizar e imputar los datos de developer a publisher. No eliminaremos estas filas dado que el resto de columnas tiene información relevante para nuestro proyecto. Por ahora decidimos dejarlos así.

# %% [markdown]
# Análisis columnas tags y genres
#
# En el análisis preliminar, se pudo advertir que estas columnas comparten información respecto del género del videojuego. Aún así, hay valores que no corresponden al género de videojuego, como 'Free to Play' y 'Early Acces', que eliminaremos.

# %%
# Revisamos los valores de 
df_games_clean.isnull().sum()
# Out:
# publisher       8052
# genres          3283
# app_name           2
# release_date    2067
# tags             163
# price           1377
# id                 2
# developer       3299
# dtype: int64

# %%
# Revisamos todos los géneros 
all_genres=df_games_clean['genres'].explode().unique().tolist()
all_genres
# Out:
# ['Action',
#  'Casual',
#  'Indie',
#  'Simulation',
#  'Strategy',
#  'Free to Play',
#  'RPG',
#  'Sports',
#  'Adventure',
#  None,
#  'Racing',
#  'Early Access',
#  'Massively Multiplayer',
#  'Animation &amp; Modeling',
#  'Video Production',
#  'Utilities',
#  'Web Publishing',
#  'Education',
#  'Software Training',
#  'Design &amp; Illustration',
#  'Audio Production',
#  'Photo Editing',
#  'Accounting']

# %%
# Revisamos el contenido de los tags, en busca de palabras clave asociadas al género del video juego.
all_tags=df_games_clean['tags'].explode().unique().tolist()
len(all_tags)
# Out:
# 340

# %% [markdown]
# *Hay 340 tipos de 'tags' en la columna tags. La estrategia a utilizar será completar los valores faltantes de genres con la columna tags.*

# %%
# Se actualiza la columna genres con los valores de tags:
df_games_clean.loc[:, 'genres'] = df_games_clean['genres'].fillna(df_games_clean['tags'])

# %% [markdown]
# En columna 'tag' también podemos encontrar el género de la película en muchos casos, por tanto, se podría utilizar alguna estrategia para rellenar los datos faltantes en 'genre'. Por otro lado, se identifican algunos géneros listados que no lo son: 'Free to Play', 'Early Acces', que se eliminarán de 'genre'.

# %%
df_games_clean.isnull().sum()
# Out:
# publisher       8052
# genres           139
# app_name           2
# release_date    2067
# tags             163
# price           1377
# id                 2
# developer       3299
# dtype: int64

# %%
all_genres=df_games_clean['genres'].explode().unique().tolist()
print(len(all_genres))
# Out:
# 304

# %% [markdown]
# *Como vemos, nuestro listado de géneros aumentó a 304, necesitamos simplificar y reducir este listado más adelante al seleccionar un sólo tipo de género listado para cada juego. Hacemos algunas modificaciones en este nuevo listado.*

# %%
df_games_clean['genres'] = df_games_clean['genres'].replace('Politics', 'Political')
# Reemplazar '&amp;' por '&' en la columna 'genres'
df_games_clean['genres'] = df_games_clean['genres'].astype(str).str.replace('&amp;', '&', regex=False)

# %%
# Convertir los valores nulos a cadenas vacías para evitar errores
df_games_clean['genres'] = df_games_clean['genres'].fillna('')

# Eliminar los términos específicos de la columna 'genres'
df_games_clean['genres'] = df_games_clean['genres'].str.replace(
    r'\b(Free to Play|Early Access|First-Person|Singleplayer|Difficult|Great Soundtrack|Multiplayer|Local Multiplayer|Asynchronous Multiplayer|4 Player Local|Soundtrack|Funny|Software)\b,?\s?', 
    '', 
    regex=True
)

# %%
all_genres_ev=df_games_clean['genres'].explode().unique().tolist()

# %%
all_genres_ev
# Out:
# ["['Action', 'Casual', 'Indie', 'Simulation', 'Strategy']",
#  "['', 'Indie', 'RPG', 'Strategy']",
#  "['Casual', '', 'Indie', 'Simulation', 'Sports']",
#  "['Action', 'Adventure', 'Casual']",
#  "['Action', 'Indie', 'Casual', 'Sports']",
#  "['Action', 'Adventure', 'Simulation']",
#  "['', 'Indie', 'Simulation', 'Sports']",
#  "['Casual', 'Indie', 'Racing', 'Simulation']",
#  "['Action', 'Indie', 'Simulation', '']",
#  "['Casual']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'RPG']",
#  "['Casual', 'Indie']",
#  "['Casual', 'Indie', 'Simulation']",
#  "['Adventure', 'Casual', 'Indie', 'Simulation', 'Strategy']",
#  "['', 'Indie', 'VR']",
#  "['', 'Action', 'Adventure', 'Indie', 'Casual']",
#  "['Action', 'Adventure', 'Indie']",
#  "['', 'Strategy', 'Action', 'Indie', 'Casual', 'VR']",
#  "['Racing', 'Simulation', 'Sports']",
#  "['Action', 'Indie']",
#  "['Design & Illustration', 'Tutorial']",
#  "['Action', 'Indie', 'Racing']",
#  "['Action']",
#  "['Action', 'Indie', 'RPG']",
#  "['Action', 'Indie', 'VR']",
#  "['Casual', 'Indie', 'Strategy']",
#  "['Action', 'Casual', 'Indie', 'Massively ', 'Simulation', 'Sports', 'Strategy']",
#  "['Adventure', 'Casual', 'Indie']",
#  "['Action', '', 'Strategy']",
#  "['Action', 'Adventure', 'RPG']",
#  "['Adventure', 'Casual', 'Indie', 'RPG']",
#  "['Strategy']",
#  "['Indie', 'Massively ', 'RPG', '']",
#  "['Adventure', '', 'RPG', '']",
#  "['', 'Indie', 'Action', 'VR']",
#  "['Action', 'Indie', 'Strategy', '']",
#  "['Action', 'Adventure', 'Indie', 'RPG', 'Strategy']",
#  "['Action', 'Adventure', 'Indie', 'RPG']",
#  "['Casual', 'Strategy', '']",
#  "['Education']",
#  "['Simulation', 'Sports', 'Casual', 'Indie', 'Golf', 'VR']",
#  "['Adventure', 'Casual', '', 'Indie']",
#  "['Indie', 'Strategy']",
#  "['Indie', 'Simulation']",
#  "['Racing']",
#  "['Adventure', 'RPG']",
#  "['Action', 'Adventure']",
#  "['RPG']",
#  'None',
#  "['Indie', 'RPG']",
#  "['Action', 'RPG']",
#  "['RPG', 'Casual', 'Adventure']",
#  "['Action', 'Adventure', 'Strategy']",
#  "['Simulation']",
#  "['Simulation', 'Strategy']",
#  "['Casual', 'Simulation']",
#  "['Adventure']",
#  "['Sports']",
#  "['Adventure', 'Indie']",
#  "['Indie']",
#  "['Strategy', 'Simulation']",
#  "['RPG', 'Strategy']",
#  "['Indie', 'Casual']",
#  "['Action', 'Simulation', 'Strategy']",
#  "['Indie', 'Casual', 'Sports']",
#  "['Action', 'Indie', 'Strategy']",
#  "['Strategy', 'Indie']",
#  "['Casual', 'Strategy']",
#  "['RPG', 'Massively ']",
#  "['Massively ', 'RPG']",
#  "['Indie', 'Simulation', 'Strategy']",
#  "['Action', 'Simulation']",
#  "['Horror', 'Lovecraftian', 'Survival Horror', '', 'Based On A Novel', 'FPS', 'Adventure', 'Atmospheric', 'Stealth', '', 'Story Rich', 'Action', 'Classic', 'Survival', 'Shooter', '', 'Gore', 'Dark']",
#  "['Open World', 'RPG', 'Fantasy', '', 'Moddable', '', 'Exploration', 'Adventure', '', 'Action', 'Magic', 'Sandbox', 'Character Customization', 'Atmospheric', 'Story Rich', 'Medieval', 'Action RPG', 'Classic', 'Third Person', 'Dark Fantasy']",
#  "['Simulation', 'Sports']",
#  "['Action', 'Adventure', 'Racing', 'Simulation', 'Strategy']",
#  "['Action', 'Racing']",
#  "['Action', 'Casual']",
#  "['Strategy', 'RTS', 'Fantasy', 'Classic', 'Third Person', 'Surreal', 'Real-Time', 'RPG', 'Action', '', 'Magic', '']",
#  "['Adventure', 'Casual']",
#  "['Hidden Object', 'Female Protagonist', 'Puzzle']",
#  "['Action', 'RPG', 'Indie']",
#  "['Strategy', 'Indie', 'Simulation']",
#  "['Action', '', 'Indie']",
#  "['Strategy', 'Casual']",
#  "['Action', 'Casual', 'Indie']",
#  "['Action', 'Adventure', 'Casual', 'RPG']",
#  "['Platformer', '', '', 'Isometric', '3D Platformer', 'Classic', 'Retro']",
#  "['Strategy', 'RPG']",
#  "['RPG', 'Casual']",
#  "['RPG', 'Indie']",
#  "['Action', 'RPG', 'Massively ']",
#  "['Adventure', 'Casual', 'Simulation']",
#  "['Adventure', 'Casual', 'Indie', 'Simulation']",
#  "['Indie', 'RPG', 'Strategy']",
#  "['Indie', 'Racing']",
#  "['Arcade', '2D', 'Platformer']",
#  "['Retro', 'Cyberpunk', 'Action', 'Platformer', '2D']",
#  "['Platformer', '2D']",
#  "['RPG', 'Simulation', 'Strategy']",
#  "['Platformer', 'Action', '2D', 'Retro']",
#  "['Action', 'Strategy', 'Indie', 'Sports']",
#  '[\'Platformer\', \'Classic\', \'\', \'2D\', \'Retro\', \'Replay Value\', \'\', \'Fast-Paced\', \'Action\', "1990\'s", \'Family Friendly\', \'\', \'Adventure\', \'Colorful\', \'\', \'Local Co-Op\', \'Co-op\', \'Pixel Graphics\']',
#  "['Casual', 'Indie', 'Simulation', 'Strategy']",
#  "['', 'Massively ', 'RPG']",
#  "['Action', 'Casual', 'Indie', 'Strategy']",
#  "['Adventure', 'Indie', 'RPG']",
#  "['Action', '']",
#  "['Action', 'Adventure', '', 'Indie', 'Massively ', 'RPG']",
#  "['Adventure', 'Strategy', 'RPG', 'Indie']",
#  "['Action', 'Indie', 'RPG', 'Strategy']",
#  "['Adventure', 'Casual', '', 'Massively ', 'Strategy']",
#  "['Action', 'Indie', 'Racing', 'Strategy']",
#  "['Action', 'Massively ', 'Simulation']",
#  "['Racing', 'Simulation']",
#  "['Strategy', 'Indie', 'Casual', 'Simulation']",
#  "['Casual', 'Simulation', 'Strategy']",
#  "['Adventure', 'Casual', 'RPG']",
#  "['Action', 'Adventure', '', 'Massively ', 'RPG']",
#  "['Adventure', 'Strategy']",
#  "['Strategy', 'RPG', 'Indie']",
#  "['Action', '', 'Massively ']",
#  "['Casual', 'Indie', 'RPG']",
#  "['Casual', 'Indie', 'Racing']",
#  "['RPG', 'Simulation']",
#  "['Action', '', 'Indie', 'Massively ', 'RPG']",
#  "['Action', 'Indie', 'Casual']",
#  "['Platformer']",
#  "['Adventure', 'Indie', 'Strategy']",
#  "['Action', 'RPG', 'Strategy']",
#  "['Indie', 'Simulation', 'Strategy', '']",
#  "['Action', 'Strategy', 'RPG', 'Indie']",
#  "['Action', 'Casual', 'Simulation', 'Strategy']",
#  "['JRPG', 'RPG', 'Fantasy']",
#  "['JRPG', 'RPG', 'Classic', 'Sci-fi', '2D']",
#  "['Ninja', 'Platformer', 'Classic']",
#  "['JRPG', 'Classic', 'RPG', 'Sci-fi', 'Fantasy', 'Adventure', '', 'Retro', 'Anime', '2D']",
#  "['Platformer', 'Action']",
#  "['Action', 'Strategy', 'Indie', 'Casual']",
#  "['Metroidvania', 'Classic', 'Side Scroller', 'Retro', 'Action RPG']",
#  "['Adventure', 'Casual', '', 'Indie', 'RPG']",
#  "['Animation & Modeling', 'Video Production']",
#  "['Action', 'Strategy']",
#  "['Action', 'Indie', 'Simulation', 'Strategy']",
#  "['Animation & Modeling']",
#  "['Action', 'Adventure', 'Strategy', 'RPG', 'Indie']",
#  "['Action', 'Adventure', 'Indie', 'Simulation']",
#  "['Action', 'Indie', 'Simulation']",
#  "['Action', 'Adventure', 'Casual', '', 'Massively ', 'RPG', 'Simulation']",
#  "['Strategy', 'Indie', 'Casual']",
#  "['Action', 'Strategy', 'Indie']",
#  "['Action', 'Strategy', 'Casual']",
#  "['Utilities']",
#  "['Action', 'Adventure', 'Indie', 'Strategy']",
#  "['RPG', 'Web Publishing']",
#  "['RPGMaker', 'Futuristic', 'Design & Illustration', 'Game Development', 'RPG', 'Sci-fi']",
#  "['Action', '', 'Massively ', 'RPG']",
#  "['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation']",
#  "['Adventure', 'Indie', 'Simulation']",
#  "['Action', '', 'Indie', 'Strategy']",
#  "['Indie', 'Simulation', 'Sports', 'Strategy']",
#  "['Massively ']",
#  "['Casual', 'Sports']",
#  "['Education', 'Training', 'Utilities', 'Web Publishing']",
#  "['Design & Illustration', 'Web Publishing']",
#  "['Casual', 'Indie', 'RPG', 'Strategy']",
#  "['Racing', 'Sports']",
#  "['', 'MOBA', 'Strategy', '', 'Team-Based', 'Action', 'e-sports', 'Online Co-Op', 'Competitive', 'PvP', 'RTS', '', 'RPG', 'Fantasy', 'Tower Defense', 'Co-op', 'Character Customization', 'Replay Value', 'Action RPG', 'Simulation']",
#  "['Adventure', 'Indie', 'RPG', 'Strategy']",
#  "['Action', '', 'Massively ', 'Simulation']",
#  "['Simulation', 'Flight', '', 'Military', '', 'Realistic', 'War', 'Open World', 'Action', 'TrackIR', 'Shooter', 'Co-op', '', 'Sandbox', 'VR', 'Tanks', 'FPS', '', 'Massively ', 'Strategy']",
#  "['Action', 'Adventure', 'Casual', 'Indie']",
#  "['', 'World War II', 'Simulation', '', 'War', 'Flight', 'Tanks', 'Military', 'Massively ', 'Action', 'Historical', 'Realistic', 'Team-Based', 'Shooter', 'Co-op', 'Arcade', 'Strategy', 'FPS', 'Open World', 'TrackIR']",
#  "['', 'Massively ', 'Simulation']",
#  "['Action', 'Adventure', 'Indie', 'RPG', '']",
#  "['Action', 'Racing', 'Simulation', 'Sports']",
#  "['Action', 'Adventure', 'Casual', 'Strategy']",
#  "['', 'Indie', 'Simulation', 'Sports', '']",
#  "['Action', 'Adventure', 'RPG', 'Simulation', 'Strategy']",
#  "['Action', 'RPG', 'Simulation']",
#  "['Adventure', 'Casual', 'Indie', 'RPG', 'Strategy']",
#  "['Indie', 'RPG', 'Simulation', 'Strategy']",
#  "['Indie', 'RPG', 'Simulation', '']",
#  "['', 'Simulation']",
#  "['Action', 'Indie', 'RPG', '']",
#  "['Action', 'Indie', 'Sports']",
#  "['Animation & Modeling', 'Design & Illustration', 'Education', 'Training', 'Utilities']",
#  "['Adventure', '', 'Indie']",
#  "['Design & Illustration']",
#  "['Animation & Modeling', 'Education', 'Utilities', 'Web Publishing']",
#  "['Adventure', '', 'Indie', 'Massively ', 'RPG', 'Strategy']",
#  "['Action', 'Adventure', '', 'Indie']",
#  "['Action', 'Casual', 'Indie', 'Simulation']",
#  "['Action', 'Adventure', 'Indie', 'Massively ', 'RPG']",
#  "['Indie', 'Massively ', 'Strategy']",
#  "['Adventure', 'RPG', 'Strategy']",
#  "['Education', 'Training']",
#  "['Casual', '', 'Indie']",
#  "['Action', 'Adventure', 'Casual', 'Racing']",
#  "['Casual', 'Animation & Modeling', 'Audio Production', 'Utilities']",
#  "['Animation & Modeling', 'Web Publishing']",
#  "['Audio Production', 'Utilities']",
#  "['Adventure', '', 'Indie', 'RPG']",
#  "['Action', 'Racing', '']",
#  "['Casual', 'Indie', 'Strategy', '']",
#  "['Animation & Modeling', 'Design & Illustration']",
#  "['Audio Production', 'Utilities', 'Video Production']",
#  "['', 'Indie', 'Massively ', 'RPG']",
#  "['Casual', 'Racing']",
#  "['Action', 'Adventure', 'Indie', 'Racing']",
#  "['Action', 'Indie', '']",
#  "['Indie', 'Racing', 'Sports']",
#  "['Action', 'Racing', 'Sports']",
#  "['Casual', 'RPG']",
#  "['Action', 'Casual', 'Indie', '']",
#  "['Action', 'Casual', 'Indie', 'Racing', 'Simulation']",
#  "['', 'Indie', 'Strategy']",
#  "['Action', 'Racing', 'Simulation', 'Strategy']",
#  "['Casual', 'Indie', 'RPG', 'Simulation']",
#  "['Action', 'Adventure', 'Casual', '', 'RPG']",
#  "['Action', 'Adventure', 'Indie', 'Simulation', '']",
#  "['Action', 'Indie', 'Massively ', 'RPG', 'Simulation']",
#  "['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation', 'Strategy', '']",
#  "['Action', 'Casual', 'Indie', 'Sports']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Strategy']",
#  "['Action', 'Casual', '', 'Indie', 'Massively ', '']",
#  "['Casual', '', 'Indie', 'Simulation', 'Strategy']",
#  "['Indie', 'Strategy', '']",
#  "['Adventure', 'Indie', 'RPG', 'Simulation', 'Strategy']",
#  "['Adventure', 'Indie', 'RPG', 'Simulation']",
#  "['Action', 'Massively ', 'RPG']",
#  "['Indie', 'Game Development', 'Documentary', 'Gaming']",
#  "['Adventure', 'Puzzle', 'Indie', 'Walking Simulator', 'Atmospheric', 'Surreal', '', 'Strategy', 'Exploration', '', '', 'VR']",
#  "['Design & Illustration', 'Photo Editing']",
#  "['Action', 'Adventure', '', 'Indie', 'Massively ', 'RPG', 'Strategy']",
#  "['Simulation', 'Indie']",
#  "['Simulation', 'Indie', 'Realistic', 'VR', 'Level Editor', 'Sandbox', '', 'Adventure']",
#  "['Action', '', 'Indie', 'Massively ']",
#  "['', 'Simulation', 'Adventure', 'Underwater', 'Exploration', 'VR', '', 'Indie', 'Open World', 'Co-op', '', 'Relaxing', '', 'Female Protagonist', 'Atmospheric']",
#  "['Action', 'Adventure', '', 'Indie', 'RPG']",
#  "['Action', 'Indie', 'Racing', 'Simulation', 'Sports', '']",
#  "['Casual', '', 'Indie', 'Massively ', 'Strategy']",
#  "['Video Production']",
#  "['Adventure', '', 'Massively ', 'RPG', 'Strategy']",
#  "['Action', 'Adventure', 'RPG', 'Strategy']",
#  "['Simulation', 'Sports', 'Strategy']",
#  "['Indie', 'Simulation', '']",
#  "['']",
#  "['Action', '', 'Massively ', 'RPG', 'Strategy']",
#  "['Action', 'Indie', 'Simulation', 'Sports']",
#  "['Sports', 'Strategy']",
#  "['Music']",
#  "['Action', 'Adventure', 'Racing']",
#  "['Action', 'Casual', '', 'Massively ']",
#  "['Horror']",
#  "['Action', 'Casual', 'Strategy']",
#  "['Casual', '', 'Indie', 'Strategy']",
#  "['Adventure', 'Simulation']",
#  "['Action', 'Adventure', '', 'Simulation', 'Sports']",
#  "['Indie', 'Racing', 'Sports', '']",
#  "['Action', 'Adventure', 'Indie', 'Massively ', 'RPG', 'Simulation', 'Strategy', '']",
#  "['Action', 'Adventure', 'Casual', '', 'RPG', 'Strategy']",
#  "['Action', 'Adventure', 'Indie', 'RPG', 'Simulation', 'Strategy', '']",
#  "['Adventure', 'Indie', '']",
#  "['Animation & Modeling', 'Design & Illustration', 'Education', 'Training', 'Utilities', 'Web Publishing']",
#  "['Massively ', 'RPG', '']",
#  "['Indie', '']",
#  "['', 'Indie']",
#  "['', 'Strategy']",
#  "['Adventure', 'Indie', 'RPG', '']",
#  "['Adventure', 'Casual', 'Indie', 'RPG', '']",
#  "['Action', 'Adventure', 'Casual', '', 'Indie', 'RPG', 'Strategy']",
#  "['Action', 'Adventure', 'RPG', '']",
#  "['Action', 'Casual', 'Indie', 'Racing', 'Sports']",
#  "['Indie', 'Massively ', 'Simulation', 'Strategy']",
#  "['Action', '', '']",
#  "['Racing', 'Simulation', 'Driving', 'Sports', '', 'Realistic', 'VR', 'Moddable', 'Indie', 'Controller', '', 'Physics', 'Replay Value', 'TrackIR', 'Open World', '', 'Action', '3D Vision', 'Artificial Intelligence', 'Arcade']",
#  "['Casual', 'Indie', 'Simulation', 'Strategy', '']",
#  "['Action', 'RPG', 'Indie', 'FPS', 'Procedural Generation', '', 'Rogue-like', 'Sci-fi', 'Rogue-lite', 'Futuristic', 'Action RPG', 'VR', 'Stealth']",
#  "['Action', 'Sports']",
#  "['Racing', 'Sports', 'Action', 'Casual', 'Simulation', 'Indie']",
#  "['VR', '', 'Education', 'Indie', 'Action', 'Casual', 'Sci-fi', '', 'Science', 'Exploration', 'Dynamic Narration', '', '3D Vision', 'Comedy', 'Racing', 'Physics', 'Simulation', 'Space']",
#  "['Casual', '', 'Indie', 'Simulation']",
#  "['Design & Illustration', 'Education', 'Utilities']",
#  "['Design & Illustration', 'Education']",
#  "['Action', 'Adventure', 'Indie', '']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'RPG', 'Strategy']",
#  "['Action', '', 'Indie', 'RPG']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'RPG', '']",
#  "['Indie', 'Massively ', 'RPG', 'Strategy', '']",
#  "['Animation & Modeling', 'Design & Illustration', 'Education', 'Training', 'Utilities', '']",
#  "['Action', 'Adventure', 'Indie', 'Strategy', '']",
#  "['Action', 'Massively ', 'Racing']",
#  "['Action', 'Indie', 'Racing', '']",
#  "['Comic Book', 'Indie']",
#  "['', '', 'Casual', 'Adventure', 'Action', 'Indie', 'RPG', 'VR', 'Sandbox']",
#  "['Adventure', 'Indie', 'Massively ', 'RPG', 'Strategy']",
#  "['Animation & Modeling', 'Design & Illustration', 'Utilities', 'Video Production']",
#  "['', 'Racing', 'Sports']",
#  "['Casual', 'Indie', 'Sports']",
#  "['Action', 'Casual', '', 'RPG', 'Simulation', 'Strategy']",
#  "['Action', 'Casual', 'RPG', 'Simulation', 'Strategy']",
#  "['Indie', 'Racing', 'Simulation', 'Sports']",
#  "['Action', 'Adventure', '', 'Massively ']",
#  "['Simulation', 'Strategy', '']",
#  "['Action', '', 'RPG']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Strategy', '']",
#  "['Action', 'Adventure', 'Casual', '', 'Massively ', 'RPG']",
#  "['Adventure', 'RPG', 'Strategy', '']",
#  "['Racing', 'Documentary']",
#  "['Action', 'Casual', 'Indie', 'Racing']",
#  "['Action', 'Adventure', '']",
#  "['Audio Production']",
#  "['Indie', 'RPG', 'Simulation']",
#  "['RPG', 'Strategy', '']",
#  "['Game Development', 'Documentary', 'Retro', 'Gaming']",
#  "['Action', 'Casual', '', 'Massively ', 'Sports']",
#  "['Adventure', 'RPG', 'Simulation', 'Strategy']",
#  "['Action', '', 'Massively ', 'RPG', '']",
#  "['', 'Racing', 'Simulation', 'Sports']",
#  "['Fighting', 'Action', 'Episodic', '']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Simulation']",
#  "['Design & Illustration', 'Utilities', 'Web Publishing']",
#  "['Action', 'Adventure', 'Casual', '', 'Indie', 'Massively ', 'RPG', '']",
#  "['Simulation', 'Indie', 'Action', 'Memes', '']",
#  "['Simulation', 'VR', '', '', 'Exploration', 'Cinematic', 'Atmospheric', '', 'Movie', 'Casual']",
#  "['Animation & Modeling', 'Design & Illustration', 'Video Production']",
#  "['Action', 'Casual', 'Indie', 'Racing', 'Simulation', 'Sports']",
#  "['Casual', '']",
#  "['Indie', 'Massively ', 'RPG', 'Strategy']",
#  "['Simulation', 'Sports', '']",
#  "['Casual', 'Adventure', 'Indie', 'Puzzle', 'VR']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'RPG', 'Simulation', 'Strategy']",
#  "['Indie', 'Sports']",
#  "['Football', 'Movie', 'Comedy', 'Soccer', 'Gaming']",
#  "['Adventure', 'Indie', 'Racing']",
#  "['Adventure', 'Casual', '', 'Indie', 'RPG', 'Simulation', 'Strategy']",
#  "['Horror', 'Survival Horror', 'Indie', 'Rogue-like', '', '', 'Survival', 'Rogue-lite', 'Atmospheric', '', 'VR', 'Procedural Generation', 'Stealth', 'Perma Death', 'Action']",
#  "['Training', 'Audio Production', 'Utilities', 'Video Production']",
#  "['Adventure', 'Simulation', 'VR']",
#  "['Action', '', 'RPG', 'Strategy']",
#  "['Casual', 'Indie', '']",
#  "['Simulation', 'Indie', 'Casual', '', 'Action', '', '', 'Cute', '', 'Family Friendly', 'Destruction', 'Kickstarter', 'Comedy', 'Procedural Generation', 'Adventure', 'Sandbox', 'VR']",
#  "['Action', 'Strategy', '']",
#  "['Animation & Modeling', 'Game Development', 'Tutorial', 'Gaming']",
#  "['Casual', 'Simulation', 'Sports', 'Strategy']",
#  "['Action', 'Adventure', 'Indie', 'RPG', 'Simulation', 'Strategy']",
#  "['Racing', 'Simulation', '']",
#  "['Indie', 'Simulation', 'Sports', 'Strategy', '']",
#  "['Action', 'Adventure', 'Indie', 'Massively ', 'Simulation', '']",
#  "['Casual', '', 'Massively ', 'Simulation']",
#  "['Action', 'Indie', 'Sports', '']",
#  "['Action', 'Casual', 'Indie', 'RPG', 'Strategy']",
#  "['Animation & Modeling', 'Design & Illustration', 'Utilities']",
#  "['Animation & Modeling', 'Design & Illustration', 'Education', 'Utilities', '']",
#  "['Casual', '', 'Indie', 'RPG']",
#  "['Action', 'Indie', 'RPG', 'Simulation', '']",
#  "['Casual', 'Simulation', 'Sports']",
#  "['Action', 'Adventure', 'Casual', '', 'Indie', '']",
#  "['', 'Horror', 'Survival', '', '', 'Adventure', '', 'Survival Horror', 'Walking Simulator', 'Dark', 'Open World', 'Indie', 'Action', 'Zombies', 'Short', 'VR', 'Co-op', 'FPS', 'Massively ', 'Comedy']",
#  "['Action', 'Massively ', '']",
#  "['Adventure', 'Casual', 'Indie', 'Strategy']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Simulation', 'Strategy']",
#  "['Adventure', 'Indie', 'Simulation', 'Strategy']",
#  "['', 'Simulation', 'Strategy']",
#  "['Action', 'Casual', 'Indie', 'RPG', '']",
#  "['Tutorial', 'Gaming', 'Game Development']",
#  "['Adventure', 'Indie', 'Mystery', 'Choices Matter', 'Female Protagonist', 'Third Person', 'Dark Humor', 'Noir', 'Crime', 'Dark', 'Story Rich', 'Thriller', '', '', 'Narration', 'Mature', 'Atmospheric', 'Casual', 'Satire', '']",
#  "['Indie', 'Documentary', 'Gaming']",
#  "['Action', 'Indie', 'Racing', 'Sports']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Massively ', 'RPG', 'Simulation', 'Strategy']",
#  "['Thriller', 'Movie', 'Mystery', 'Drama']",
#  "['Casual', 'Racing', 'Sports']",
#  "['Casual', '', 'Strategy']",
#  "['Movie', 'Crime', 'Comedy', 'Thriller']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Simulation', 'Sports']",
#  "['', 'RPG', 'Strategy']",
#  "['Action', 'Indie', 'Massively ']",
#  "['', 'Sports']",
#  "['Horror', 'Movie', 'Drama', 'Thriller']",
#  "['Adventure', 'Casual', 'Simulation', 'Strategy']",
#  "['Action', 'Simulation', 'Strategy', '']",
#  "['Action', 'Casual', '', 'Strategy']",
#  "['Action', 'Casual', '', 'Indie', 'RPG']",
#  "['Action', 'Massively ', 'Racing', 'RPG', 'Simulation']",
#  "['Indie', 'Documentary', 'Action-Adventure']",
#  "['Indie', 'Horror', 'Short']",
#  "['Drama', 'Movie', 'Comedy', 'Indie']",
#  "['Action', 'Casual', '', 'Indie', 'RPG', 'Strategy']",
#  "['Indie', 'Horror', 'Thriller', 'Movie', 'Drama']",
#  "['Action', '', 'Indie', '']",
#  "['Drama', 'Crime', 'Movie', 'Indie', 'Comedy']",
#  "['Casual', 'Indie', 'Sports', 'Strategy']",
#  "['Action', 'Casual', 'Massively ']",
#  "['Action', 'Casual', 'Indie', 'RPG', 'Simulation', 'Strategy']",
#  "['', 'Simulation', 'Indie']",
#  "['Action', 'Casual', 'Indie', 'RPG']",
#  "['Action', 'Casual', 'Racing']",
#  "['Indie', 'Simulation', 'Sports', '']",
#  "['Movie', 'Drama', 'Action-Adventure']",
#  "['Documentary', 'Drama', 'Memes', 'Anime', 'Comedy', 'Nudity']",
#  "['Movie', 'Romance', 'Drama']",
#  "['Action', 'Indie', 'Racing', 'Simulation']",
#  "['Action', 'Simulation', 'Sports']",
#  "['Drama', 'Indie', 'Movie', 'Romance']",
#  "['Movie', 'Indie', 'Thriller', 'Foreign']",
#  "['', 'Indie', 'Massively ', 'Strategy']",
#  "['Indie', 'RPG', 'Sports', 'Strategy', '']",
#  "['Adventure', 'Indie', 'Simulation', 'Strategy', '']",
#  "['Indie', 'Casual', 'Strategy', 'Puzzle']",
#  "['Drama', 'Movie', 'Indie', 'Comedy']",
#  "['Action', 'Indie', 'RPG', 'Strategy', '']",
#  "['Adventure', 'Casual', 'Indie', 'Sports']",
#  "['Indie', 'Thriller', 'Short']",
#  "['Action', '', 'Indie', 'Massively ', 'Simulation']",
#  "['Casual', 'Indie', 'Simulation', 'Sports', 'Strategy']",
#  "['Action', 'Casual', '', 'Indie']",
#  "['Action', 'Adventure', 'Casual', 'Indie', '']",
#  "['Action', '', 'Indie', 'Massively ', 'Sports']",
#  "['', 'RPG']",
#  "['Adventure', 'Indie', 'Massively ', 'RPG']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'RPG', 'Simulation', 'Strategy', '']",
#  "['Adventure', '']",
#  "['Movie', 'Action', 'Thriller', 'Feature Film']",
#  "['Movie', 'Action', 'Action-Adventure', 'Thriller', 'Post-apocalyptic', 'Feature Film', 'Female Protagonist']",
#  "['Documentary', 'Gaming']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'RPG', 'Simulation']",
#  "['', 'Space', 'Co-op', 'Simulation', 'Adventure', 'Open World', 'Space Sim', 'Action', '', 'Survival', 'Indie', 'Sci-fi', 'Online Co-Op', 'Exploration', '', 'Sandbox', '', 'FPS', 'Rogue-like', 'Strategy']",
#  "['', 'Massively ']",
#  "['Indie', 'RPG', 'Simulation', 'Strategy', '']",
#  "['Comedy', 'Movie']",
#  "['Animation & Modeling', 'Design & Illustration', 'Web Publishing']",
#  "['Adventure', 'Indie', 'Strategy', '']",
#  "['Adventure', 'Casual', '']",
#  "['Action', 'Adventure', 'Indie', 'Procedural Generation', 'Rogue-like', 'Perma Death']",
#  "['Adventure', 'Indie', 'Psychological Horror', 'Mystery', 'Horror', 'Puzzle', 'Surreal', 'Story Rich', 'Atmospheric', 'Thriller', '']",
#  "['Audio Production', 'Design & Illustration', 'Photo Editing', 'Utilities', 'Video Production', 'Web Publishing']",
#  "['Adventure', 'Indie', 'RPG', 'Simulation', '']",
#  "['Action', 'Indie', 'Anime', 'Platformer', 'Female Protagonist', '', 'Physics']",
#  "['Animation & Modeling', 'Utilities']",
#  "['Training']",
#  "['', 'Sports', 'Strategy']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Racing']",
#  "['Action', '', 'Simulation', 'Strategy']",
#  "['Movie', 'Drama']",
#  "['Action', 'Adventure', 'Indie', 'Massively ', 'RPG', '']",
#  "['Adventure', 'Indie', 'Action']",
#  "['Tutorial', 'Animation & Modeling']",
#  "['Animation & Modeling', 'Tutorial']",
#  "['Drama', 'Short']",
#  "['Indie', 'Racing', '']",
#  "['', 'FPS', 'Gaming', 'Shooter', 'Action', '', 'Documentary', 'Episodic', 'Online Co-Op', '', 'Massively ', '', 'Casual', 'Adventure', 'Action-Adventure', 'Anime', 'Games Workshop', 'Physics', 'Pixel Graphics', 'Drama']",
#  "['Indie', 'Casual', 'Adventure', 'VR', 'Pirates', 'Exploration']",
#  "['Horror', 'Drama', 'Short']",
#  "['Action', 'Adventure', '', 'RPG', 'Simulation']",
#  "['Casual', '', 'Indie', 'RPG', 'Simulation', 'Strategy']",
#  "['Horror', 'Indie', 'Strategy', 'Action', 'Psychological Horror', 'Survival', 'Atmospheric', '', '']",
#  "['Design & Illustration', 'Photo Editing', 'Utilities']",
#  "['Action', 'Casual', 'Indie', 'Simulation', 'Sports', '']",
#  "['Casual', 'Indie', 'Massively ', 'Strategy']",
#  "['Tutorial', 'Design & Illustration']",
#  "['Action', 'Adventure', 'Indie', 'RPG', 'Strategy', '']",
#  "['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation', 'Strategy']",
#  "['Indie', 'Casual', 'Cute']",
#  "['Hardware', 'Steam Machine', 'Simulation', '', 'Atmospheric', 'Mod', '', 'Puzzle', 'Local Co-Op', 'Psychedelic']",
#  "['Gaming', '', 'Documentary', 'Episodic', 'MOBA', '', 'Competitive', 'Action', 'Adventure', 'Movie', 'Casual', 'Family Friendly', 'Strategy']",
#  "['', 'Massively ', 'Strategy']",
#  "['Action', 'Indie', 'RPG', 'Simulation']",
#  "['Casual', '', 'Indie', 'Strategy', '']",
#  "['', 'Massively ', 'Simulation', 'Sports']",
#  "['Simulation', 'Indie', 'Action', 'Arcade', 'Platformer', 'Retro']",
#  "['Design & Illustration', 'Animation & Modeling', 'Tutorial']",
#  "['Tutorial', 'Design & Illustration', 'Animation & Modeling']",
#  "['Indie', 'RPG', '']",
#  "['Action', 'Adventure', 'Simulation', '']",
#  "['Horror', 'Survival Horror', 'Indie', 'Action', 'Adventure', 'Strategy', 'Simulation', 'Psychological Horror', 'VR', '', '', 'Memes', '', 'Walking Simulator', '', 'Co-op', 'Female Protagonist']",
#  "['Action', '', 'Massively ', 'Simulation', 'Strategy']",
#  "['Movie', 'Retro', '1980s']",
#  "['Action', 'Adventure', 'Indie', 'RPG', 'Simulation']",
#  "['Action', 'Adventure', 'Sports']",
#  "['Audio Production', 'Education', 'Training', 'Video Production', 'Web Publishing']",
#  "['Action', 'Indie', 'Simulation', 'Strategy', '']",
#  "['Action', 'Indie', 'Massively ', 'RPG', '']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'RPG', 'Strategy', '']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Massively ', 'Simulation']",
#  "['Adventure', 'Casual', 'Strategy']",
#  "['Casual', '', 'Massively ', 'Sports', 'Strategy']",
#  "['Accounting']",
#  "['Action', 'RPG', '']",
#  "['RPG', 'Indie', 'Action', 'Open World', 'FPS', 'Robots', 'VR', 'Procedural Generation', 'Co-op', '', '', 'Sci-fi', 'Gun Customization', 'Futuristic', 'Building', 'Stealth', 'Action RPG', 'Atmospheric', 'Multiple Endings', 'Sandbox']",
#  "['Indie', 'Massively ', 'RPG']",
#  "['Psychological Horror', 'Casual', 'VR', 'Memes', 'Nudity', '', 'Illuminati', 'Anime', 'Dating Sim', 'Horror', 'Gore', 'Survival Horror']",
#  "['Indie', 'Racing', 'Simulation', 'Sports', '']",
#  "['Action', 'Casual', '', 'Indie', 'Strategy']",
#  "['', 'Indie', 'Massively ', 'Simulation', 'Sports', 'Strategy']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Simulation', 'Strategy', '']",
#  "['', 'Indie', 'Massively ', 'RPG', 'Strategy', '']",
#  "['Comedy', 'Movie', 'Fantasy']",
#  "['Adventure', 'Casual', 'Indie', '']",
#  "['Audio Production', 'Training', 'Utilities', 'Video Production', 'Web Publishing']",
#  "['Racing', 'Action', 'Indie', 'Procedural Generation', '', 'Runner', 'Fast-Paced']",
#  "['Action', 'Adventure', 'Massively ', '']",
#  "['', '']",
#  "['Adventure', 'Casual', '', 'Indie', 'Massively ', 'RPG', 'Strategy']",
#  "['Indie', 'RPG', 'Strategy', '']",
#  "['Casual', 'Indie', 'RPG', 'Simulation', 'Strategy']",
#  "['Casual', 'Indie', 'RPG', 'Simulation', 'Sports', 'Strategy']",
#  "['', 'Simulation', 'Indie', '', 'VR']",
#  "['', 'Indie', 'Massively ', 'RPG', 'Strategy']",
#  "['', 'Massively ', 'RPG', 'Strategy']",
#  "['', 'Indie', 'RPG', 'Simulation']",
#  "['Action', '6DOF', '', 'Space', 'Shooter', '', '']",
#  "['Action', 'Casual', 'Indie', 'Simulation', 'Sports', 'Strategy']",
#  "['', 'Indie', 'RPG', 'Strategy', '']",
#  "['Short', 'Drama']",
#  "['Comedy', 'Movie', 'Drama']",
#  "['', 'Education', 'Training', 'Utilities']",
#  "['Action', 'Adventure', 'RPG', 'Indie', 'VR', '']",
#  "['Action', 'Adventure', 'Indie', 'Racing', 'Simulation', 'Sports']",
#  "['Action', 'Adventure', 'Casual', 'Racing', 'RPG', 'Sports', 'Strategy']",
#  "['', 'Indie', 'Simulation', '']",
#  "['Racing', 'VR', 'Sci-fi', 'Indie', 'Action', 'Futuristic', 'Arcade']",
#  "['Adventure', 'Indie', 'Space', 'VR', '', 'Walking Simulator', 'Survival', 'Atmospheric', '', 'Simulation', 'Sci-fi', 'Female Protagonist']",
#  "['Adventure', 'Indie', 'Simulation', '']",
#  "['Utilities', 'VR']",
#  "['Adventure', 'Indie', 'VR']",
#  "['Adventure', '', 'Indie', 'RPG', '']",
#  "['Sports', 'Indie', 'VR']",
#  "['Action', 'Adventure', 'Indie', 'Simulation', 'Strategy']",
#  "['Casual', 'RPG', 'Simulation']",
#  "['', 'Video Production', 'Utilities', 'VR']",
#  "['Indie', 'Casual', 'VR']",
#  "['Adventure', '', 'RPG', 'Indie', 'Horror', 'VR']",
#  "['VR', 'Casual', 'Strategy', 'Indie', 'Simulation', 'Action']",
#  "['', 'Action', 'Indie', 'VR']",
#  "['', 'VR', '', 'Family Friendly', 'Simulation', 'Sexual Content', 'Choices Matter', 'Atmospheric', '', 'RPG', 'Cute', 'Tactical', 'Classic', 'Surreal', 'Casual', 'Replay Value', 'Online Co-Op', 'JRPG', 'Sandbox', 'Puzzle']",
#  "['Simulation', 'Sports', 'Action', 'Indie', 'VR']",
#  "['Adventure', 'VR', 'Indie', 'Exploration', '', '', 'Replay Value', 'Atmospheric', 'Platformer', '', 'Fantasy', 'Parkour', 'Competitive', 'Open World', 'RPG', 'Racing']",
#  "['Action', 'Casual', 'Adventure', 'Indie', 'VR']",
#  "['Action', 'Simulation', 'VR']",
#  "['Action', 'Indie', 'Casual', 'VR']",
#  "['Indie', 'Sports', 'Casual', 'VR']",
#  "['', 'Simulation', 'Adventure', 'VR']",
#  "['Strategy', '']",
#  "['Casual', 'Puzzle', 'Strategy', 'Indie', 'VR']",
#  "['Casual', 'Adventure', 'Indie', '', 'VR']",
#  "['Casual', 'Action', 'Indie', 'VR']",
#  "['Indie', 'VR', 'Music', 'Music-Based Procedural Generation', 'Rhythm']",
#  "['', 'Simulation', 'Indie', 'Casual', 'Sandbox', 'Physics', 'VR', '']",
#  "['VR', 'Simulation', 'Casual', 'Indie', 'Adventure', 'Underwater']",
#  "['', 'RPG', 'Adventure', 'VR', 'Action', '']",
#  "['Action', 'Casual', 'VR']",
#  "['Indie', 'Casual', 'Simulation']",
#  "['', 'Action', 'Simulation', 'VR']",
#  "['Casual', '', 'Simulation']",
#  "['Indie', 'Casual', 'VR', 'Visual Novel']",
#  "['', 'Massively ', 'Simulation', 'Strategy']",
#  "['Action', 'Adventure', 'Indie', 'Racing', '']",
#  "['Action', 'VR', 'Zombies']",
#  "['Massively ', '', 'Casual', 'VR', 'Simulation', 'Indie', 'Adventure', '']",
#  "['Indie', 'Exploration', 'Adventure', 'Walking Simulator', 'Casual', 'Story Rich', '', '', 'Atmospheric', 'VR', 'Short', 'Horror']",
#  "['Movie', 'Action', 'Based On A Novel', 'Futuristic', 'Drama', 'Action-Adventure']",
#  "['Movie', 'Mystery', 'Drama', 'Thriller']",
#  "['Movie', 'Comedy', 'Memes', 'Psychological Horror']",
#  "['Movie', 'Zombies', 'Horror', 'Gore']",
#  "['Movie', 'Horror']",
#  "['Movie', 'Cold War', 'Drama']",
#  "['Movie', 'Horror', 'Comedy', 'Sci-fi']",
#  "['Movie', 'Horror', 'Comedy', 'Fantasy']",
#  "['Movie', 'Horror', 'Sci-fi', 'Comedy']",
#  "['Movie', 'Drama', 'Crime', 'Action', 'Thriller']",
#  "['Movie', 'Action', 'Based On A Novel', 'Survival', 'Action-Adventure']",
#  "['Movie', 'Action', 'Survival', 'Based On A Novel', 'Romance', 'Action-Adventure']",
#  "['Movie', 'Based On A Novel', 'Sci-fi', 'Action-Adventure']",
#  "['Movie', 'Futuristic', 'Based On A Novel', 'Action-Adventure']",
#  "['Movie', 'Memes', 'Drama', 'Romance', 'Vampire', 'Werewolves', 'Fantasy']",
#  "['Movie', 'Romance', 'Fantasy', 'Drama', 'Vampire', 'Werewolves']",
#  "['Movie', 'Supernatural', 'Action', 'Fantasy', 'Action-Adventure']",
#  "['Movie', 'Romance', 'Drama', 'Fantasy', 'Vampire', 'Action-Adventure', 'Werewolves']",
#  "['Movie', 'Sci-fi', 'Action', 'Comic Book']",
#  "['Movie', 'Vampire', 'Werewolves', 'Drama', 'Romance', 'Fantasy']",
#  "['Movie', 'Martial Arts', 'Action', 'Adventure', 'Fighting', 'Action-Adventure']",
#  "['Movie', 'Action', 'War', 'Thriller', 'Action-Adventure']",
#  "['Movie', 'Horror', 'Thriller', 'Detective', 'Mystery', 'Crime']",
#  "['Movie', 'Thriller', 'Horror', 'Mystery', 'Crime', 'Classic']",
#  "['Movie', 'Mystery', 'Crime', 'Horror', 'Thriller']",
#  "['Movie', 'Horror', 'Thriller', 'Mystery', 'Crime']",
#  "['Movie', 'Magic', 'Thriller', 'Crime']",
#  "['Movie', 'Crime', 'Martial Arts', 'Action', 'Thriller']",
#  '[\'Movie\', \'Crime\', "1990\'s", \'Thriller\', \'Drama\']',
#  "['Movie', 'Demons', 'Comedy', 'Horror']",
#  "['Movie', 'Action', 'Comedy']",
#  "['Movie', 'Mystery', 'Crime', 'Action']",
#  "['Movie', 'Action', 'War', 'Drama']",
#  "['Movie', 'Horror', 'Survival Horror']",
#  "['Movie', 'Drama', 'Crime', 'Horror']",
#  "['Movie', 'Comedy']",
#  "['Movie', 'Robots', 'Action', 'Sci-fi', 'Thriller']",
#  "['Movie', 'Drama', 'Action', 'Thriller']",
#  "['Movie', 'Drama', 'Comedy']",
#  "['Movie', 'Western', 'Horror', 'Vampire']",
#  "['Movie', 'Romance', 'Drama', 'Action', 'Racing', 'Sports']",
#  "['Movie', 'Detective', 'Crime', 'Horror', 'Thriller']",
#  '[\'Movie\', \'Romance\', \'Comedy\', \'Comic Book\', "1990\'s"]',
#  "['Action', 'Sports', 'Indie', 'VR']",
#  "['Adventure', 'VR']",
#  "['Indie', 'Casual', 'Simulation', 'VR']",
#  "['Anime', 'Episodic']",
#  "['', 'Adventure', 'Indie', 'Simulation', 'Action', 'VR']",
#  "['Audio Production', 'Training', 'Utilities']",
#  "['Action', 'Massively ']",
#  "['Action', 'Casual', 'Simulation']",
#  "['Sports', 'Strategy', '']",
#  "['Sports', 'Action', 'Casual', 'VR']",
#  "['Animation & Modeling', 'Audio Production', 'Training', 'Utilities', 'Video Production']",
#  "['Adventure', '', 'Massively ', 'RPG']",
#  "['Adventure', 'Indie', 'VR', '', 'Atmospheric', 'Puzzle', '', 'Sci-fi', 'Walking Simulator']",
#  "['Action', 'Casual', 'Indie', 'Sports', '']",
#  "['Action', 'Casual', '', 'Indie', 'Sports', '']",
#  "['', 'Action', 'VR']",
#  "['VR', 'Indie', 'Casual', 'Atmospheric']",
#  "['Indie', 'Animation & Modeling', 'Cinematic', 'Abstract', 'Experimental', 'VR']",
#  "['Movie', 'Action', 'Superhero', 'Fantasy', 'Comic Book', 'Action-Adventure']",
#  "['Movie', 'Action', 'Superhero', 'Fantasy', 'Sci-fi', 'Action-Adventure', 'Comic Book']",
#  "['Movie', 'Action', 'Superhero', 'Fantasy', 'Comic Book']",
#  "['Movie', 'Action', 'Superhero', 'Fantasy', 'Comic Book', 'Sci-fi', 'Action-Adventure']",
#  "['Indie', 'Programming', 'Adventure', 'Puzzle', '', 'VR', 'Hacking']",
#  "['Casual', '', 'RPG']",
#  "['Casual', 'Sports', 'VR']",
#  "['Movie', 'Supernatural', 'Adventure', 'Horror', 'Thriller']",
#  "['Movie', 'Horror', 'Detective', 'Crime', 'Demons', 'Supernatural']",
#  "['', 'Racing', 'Indie', 'Adventure', 'VR', 'Driving', '', 'Replay Value', 'Procedural Generation', 'Flight']",
#  "['Movie', 'Psychological', 'Crime', 'Horror']",
#  "['Action', 'Adventure', 'Indie', 'Massively ', 'Simulation']",
#  "['Movie', 'Demons', 'Supernatural', 'Horror']",
#  "['Movie', 'Supernatural', 'Horror']",
#  "['Movie', 'Demons', 'Supernatural']",
#  "['War', 'Assassin', 'Crime', 'Martial Arts', 'Foreign', 'Action-Adventure']",
#  "['Movie', 'Horror', 'Aliens', 'Sci-fi']",
#  "['Horror', 'Movie']",
#  "['Movie', 'Martial Arts', 'Action', 'Action-Adventure']",
#  "['Movie', 'Romance', 'Crime', 'Comedy']",
#  "['Movie', 'Drama', 'Crime', 'Action', 'Fighting']",
#  "['Movie', 'Drama', 'Crime']",
#  "['Movie', 'Romance', 'Drama', 'Classic', 'Comedy']",
#  "['Movie', 'Mystery', 'Drama', 'Supernatural', 'Horror', 'Thriller']",
#  "['Movie', 'Crime', 'Gambling', 'Action', 'Thriller']",
#  "['Movie', 'Comedy', 'Documentary']",
#  "['Movie', 'Action', 'Fantasy', 'Adventure', 'Sci-fi']",
#  "['Movie']",
#  "['Action', 'Indie', 'Racing', 'Simulation', 'Sports']",
#  "['VR', 'Adventure', 'Simulation', 'Dinosaurs', 'Indie', 'Time Travel', 'Science', 'Underwater', '', 'Exploration', 'Sci-fi', '', 'Atmospheric', 'Time Manipulation', 'Education', 'Controller', 'Mystery']",
#  "['Movie', 'World War I', 'Drama', 'Short']",
#  "['Action', 'Adventure', 'Massively ', 'RPG', 'Simulation', 'Strategy']",
#  "['Indie', 'Casual', 'Racing', 'VR']",
#  "['Action', 'Adventure', 'Indie', 'Racing', 'Sports', 'Strategy']",
#  "['Indie', 'VR', 'Music', '', 'Survival']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Racing', 'Simulation']",
#  "['Casual', 'Simulation', 'Psychological Horror', 'Horror', 'VR']",
#  "['', 'Simulation', 'Flight', 'Action', 'Strategy', 'Indie', 'Adventure', 'Military', 'Realistic', 'War', 'VR', 'Shooter', 'Open World', 'Naval', 'Sandbox', 'Moddable', '', 'Atmospheric', '', 'TrackIR']",
#  "['', 'Strategy', 'Action', 'Indie', 'VR']",
#  "['Action', 'Movie', 'Comic Book']",
#  "['Anime', 'Movie']",
#  "['Survival', 'Adventure', 'Exploration', 'VR', 'Sci-fi', 'Survival Horror', '', '', 'Atmospheric', 'Indie', 'Space', 'Story Rich', 'Simulation', 'Horror', 'Walking Simulator', 'Open World', 'Psychological Horror', 'Crafting', 'Mystery', '']",
#  "['Animation & Modeling', 'Design & Illustration', 'Utilities', '']",
#  "['Action', '', 'Indie', 'Massively ', 'RPG', 'Simulation']",
#  "['Casual', '', 'Simulation', 'Sports']",
#  "['Action', 'VR']",
#  "['Utilities', 'Video Production']",
#  "['Indie', 'Massively ', 'Strategy', '']",
#  "['Movie', 'Action', 'Based On A Novel', 'Action-Adventure', 'Futuristic']",
#  "['Casual', '', 'Massively ', 'Strategy']",
#  "['', 'Action', 'Indie', 'Simulation', 'VR']",
#  "['Simulation', 'VR', 'Retro', 'Casual', 'Arcade', 'Indie', '1980s', 'Action', 'Sports', 'Adventure', 'Racing', 'Co-op', '', 'Online Co-Op', 'Basketball', 'On-Rails Shooter']",
#  "['', 'Sports', 'Action', 'VR']",
#  "['Adventure', 'Casual', 'RPG', 'Strategy']",
#  "['Adventure', 'Action', 'Indie', 'RPG', 'Casual', '3D Platformer', 'Hack and Slash', 'Fantasy', 'Action-Adventure', 'Action RPG']",
#  "['', 'Design & Illustration', 'Animation & Modeling', 'Audio Production', 'Education']",
#  "['', 'Adventure', 'Action', 'Indie', 'Sports', 'VR']",
#  "['Simulation', 'Adventure', 'Indie', 'Casual', 'VR']",
#  "['Adventure', 'Indie', 'Action', 'VR', 'Puzzle']",
#  "['Sports', 'Action', 'Indie']",
#  "['Movie', 'Anime']",
#  "['RPG', 'VR']",
#  "['Strategy', 'Indie', 'VR']",
#  "['Movie', 'Sci-fi', 'Supernatural', 'Action', 'Horror']",
#  "['Movie', 'Action']",
#  "['', 'Strategy', 'Adventure', 'Indie', 'Casual', 'VR']",
#  "['Simulation', 'Action', 'Indie', 'Casual', 'VR']",
#  "['Action', 'Indie', 'Massively ', '']",
#  "['Action', 'Casual', 'Indie', 'VR']",
#  "['Action', 'Casual', '', 'Indie', 'RPG', 'Sports', '']",
#  "['', 'Casual', 'VR', '', 'Family Friendly', 'Horror']",
#  "['Action', 'VR', 'Star Wars', '']",
#  "['Action', 'Indie', 'Racing', 'Simulation', 'Sports', 'Strategy']",
#  "['Adventure', 'Indie', 'VR', 'Puzzle', '', 'Short', 'Horror', 'Philisophical']",
#  "['Indie', 'Racing', 'Simulation']",
#  "['Sports', 'Indie', 'Casual', '', 'VR']",
#  "['Design & Illustration', 'Utilities']",
#  "['', 'Indie', 'Casual', 'Simulation', 'VR']",
#  "['Adventure', 'VR', 'Indie', 'Story Rich', 'Exploration', 'Atmospheric', 'Mature', 'Multiple Endings', 'Interactive Fiction', 'Puzzle', 'Female Protagonist', 'Mystery', 'Sci-fi', '', 'Realistic', '', 'Drama']",
#  "['VR', 'Utilities', 'Video Production']",
#  "['Casual', 'Sports', 'Action', 'VR']",
#  "['Web Publishing']",
#  "['Action', 'Adventure', '', 'Indie', '']",
#  "['', 'Education']",
#  "['', 'Indie', 'Horror', 'VR']",
#  "['Action', 'Casual', '', 'Indie', 'RPG', 'Sports']",
#  "['Action', 'Adventure', 'Indie', 'VR']",
#  "['Action', 'Casual', 'Massively ', '']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Sports', '']",
#  "['Movie', 'Mystery', 'Horror', 'Thriller']",
#  "['Simulation', 'Action', 'Indie', 'Casual']",
#  "['', 'Casual', 'VR']",
#  "['', 'Action', 'Indie']",
#  "['Simulation', 'Memes', 'VR', 'Politics', 'Political']",
#  "['Adventure', 'Indie', 'Strategy', 'VR']",
#  "['Action', 'Simulation', 'Indie', 'Casual', 'VR']",
#  "['Adventure', 'Massively ', 'RPG']",
#  "['Documentary', 'Movie', 'Game Development', 'Gaming', 'Narration', 'Drama', 'Linear', '', 'Indie', 'Casual', 'Story Rich', '', 'Atmospheric', 'Dynamic Narration', '', 'GameMaker', 'FMV']",
#  "['Racing', 'Action', 'Indie', 'Casual']",
#  "['Strategy', 'Indie', 'VR', 'Card Game']",
#  "['Action', 'Adventure', 'Casual', 'Racing', 'Simulation', 'Sports']",
#  "['', 'Action', 'VR', '', 'Procedural Generation']",
#  "['Action', 'Casual', 'Indie', 'Simulation', 'Sports']",
#  "['Indie', 'Adventure', 'VR', 'Horror']",
#  "['Adventure', 'RPG', 'VR', 'Puzzle-Platformer', 'Platformer', 'Puzzle']",
#  "['Chess']",
#  "['Movie', 'Comedy', 'Sci-fi', 'Fantasy', 'Action-Adventure']",
#  "['', 'Casual', 'Simulation', 'Indie', 'VR']",
#  "['', 'Simulation', 'Casual', 'Space', '', 'VR', 'Racing', 'Sports', '', 'Indie', 'Procedural Generation', 'Action', 'Psychedelic', 'Family Friendly', 'Futuristic', 'Competitive', 'Sci-fi', 'Real-Time', 'Atmospheric', '']",
#  "['Movie', 'Fantasy', 'Comedy', 'Sci-fi', 'Action-Adventure']",
#  "['Fantasy', 'Comedy', 'Sci-fi', 'Movie', 'Action-Adventure']",
#  "['Action', 'Simulation', 'Casual', 'VR']",
#  "['Casual', 'VR']",
#  "['Dragons', 'Movie', 'Gaming', 'Kickstarter']",
#  "['Strategy', 'Action', 'Indie', 'Simulation', 'VR']",
#  "['', 'Action', 'Adventure', 'VR']",
#  "['Movie', 'Action', 'Fantasy', 'Crime']",
#  "['Movie', 'Martial Arts', 'Foreign', 'Action', 'Assassin']",
#  "['Documentary', 'Sports', 'Basketball']",
#  '[\'Movie\', \'Drama\', "1990\'s"]',
#  "['Action', 'Indie', 'Casual', 'Simulation', 'Racing', 'Sports']",
#  "['Action', 'Casual', 'RPG', 'VR']",
#  "['Action', 'Casual', '']",
#  "['Design & Illustration', 'VR']",
#  "['', 'Casual', 'Simulation', 'Action', 'VR', 'Platformer', '3D Platformer']",
#  "['', 'VR']",
#  "['Casual', '', 'Massively ', 'RPG', 'Simulation', 'Strategy']",
#  "['Strategy', 'Action', 'Indie', 'Casual', 'Tower Defense', 'VR']",
#  "['Anime', 'Movie', 'Detective', 'Mystery']",
#  "['Anime', 'Movie', 'Action', 'Superhero']",
#  "['Racing', 'VR']",
#  "['Movie', 'Drama', 'Music']",
#  "['', 'Racing', 'VR']",
#  "['', 'Sports', 'Action', 'Indie', 'VR', 'Space', 'Sci-fi', '', '', 'Atmospheric', 'Casual', 'e-sports']",
#  "['Strategy', 'Simulation', 'Tower Defense', 'Indie', 'Action', 'Zombies', 'Tactical', 'Military', 'War', '3D Vision', 'Realistic']",
#  '[\'\', \'Indie\', \'Action\', \'VR\', \'FPS\', \'Robots\', \'Open World\', \'Sci-fi\', \'Cyberpunk\', \'Sandbox\', \'Bullet Time\', "Shoot \'Em Up", \'Shooter\', \'Flight\']',
#  "['Action', 'Casual', 'Simulation', 'VR']",
#  "['Action', 'Adventure', 'Indie', 'RPG', 'Simulation', 'Sports']",
#  "['Movie', 'Thriller']",
#  "['Casual', '', 'Indie', 'Simulation', 'Strategy', '']",
#  "['', 'Action', 'Adventure', 'Dinosaurs', 'Indie', 'VR']",
#  "['Action', 'Adventure', 'Casual', '', 'Indie', 'Massively ', 'RPG', 'Simulation']",
#  "['Movie', 'Crime', 'Horror', 'Thriller']",
#  "['Casual', 'Action', 'Adventure', 'VR']",
#  "['Sports', 'Indie', 'Casual', 'VR']",
#  "['Adventure', 'Indie', 'RPG', 'VR']",
#  "['Indie', 'Casual', 'Simulation', 'Action', 'VR', 'Puzzle']",
#  "['', 'Action', 'Racing', 'Indie', 'VR']",
#  "['Action', 'Casual', 'Indie', 'Massively ', 'Simulation', 'Strategy', '']",
#  "['Strategy', 'Indie', 'Casual', 'VR']",
#  "['Casual', 'Simulation', 'Sports', 'Action', 'VR']",
#  "['Movie', 'Action', 'Thriller', 'Crime']",
#  "['', 'Indie', 'Massively ', 'RPG', 'Simulation', 'Strategy']",
#  "['Indie', 'Casual', 'Simulation', 'VR', 'Space Sim', 'Futuristic', 'Space', 'Perma Death', '', 'Sci-fi', 'Trading', 'Real-Time']",
#  "['Simulation', 'Indie', 'Casual', 'VR', 'Trains', 'Relaxing', 'On-Rails Shooter']",
#  "['Action', 'Indie', 'VR', 'Space', 'Sci-fi', 'Space Sim', 'Shooter', 'Third-Person Shooter', 'Arcade', 'Simulation', 'Third Person', '1980s']",
#  "['Video Production', 'Audio Production', 'VR']",
#  "['', 'Design & Illustration', 'Animation & Modeling']",
#  "['Movie', 'Family Friendly', 'Action-Adventure']",
#  "['Simulation', 'VR', 'Space']",
#  "['Movie', 'Detective', 'Crime', 'Action', 'Adventure', 'Comedy', 'Action-Adventure']",
#  "['Adventure', 'Indie', 'Action-Adventure', 'Experience', 'VR']",
#  "['Indie', 'Strategy', 'Action', 'Adventure', 'VR', 'Steampunk', 'Shooter', 'Action-Adventure']",
#  "['Adventure', '', 'RPG', 'Strategy']",
#  "['', 'Action', 'Indie', 'Shooter', 'Sci-fi', 'Adventure', 'VR']",
#  "['Adventure', 'Indie', 'Casual', 'VR']",
#  "['Action', 'Casual', '', 'Indie', 'Simulation', 'Sports', 'Strategy']",
#  "['Casual', '', 'Indie', 'Simulation', 'Sports', 'Strategy']",
#  "['Strategy', 'Indie', 'Casual', 'VR', 'Puzzle']",
#  "['', 'Action', 'Indie', 'Casual', 'VR']",
#  "['Action', 'Racing', 'VR']",
#  "['Action', 'Casual', 'Puzzle', 'VR']",
#  "['Simulation', 'Sports', 'Indie', 'Casual', 'VR']",
#  "['Politics', 'Political', 'Documentary', 'Episodic']",
#  "['Action', 'Adventure', 'Strategy', '']",
#  "['Action', 'Adventure', 'Massively ']",
#  "['Design & Illustration', 'Education', 'Photo Editing', 'Training']",
#  "['Memes', 'Anime', 'Family Friendly', 'Episodic', 'Fantasy', 'Psychological Horror', 'Action-Adventure', 'Sexual Content', 'Nudity', 'Illuminati', 'Story Rich', 'Horror', 'Gore', 'Classic', 'Cartoon']",
#  "['Anime', 'Movie', 'Psychological Horror', 'Female Protagonist', 'Cute', 'Music']",
#  "['', 'Indie', 'Adventure', 'VR']",
#  "['Action', 'Adventure', 'Indie', 'Casual', 'VR']",
#  "['Utilities', 'Education']",
#  "['Indie', 'Massively ', 'RPG', 'Simulation']",
#  "['Indie', 'Racing', 'RPG', 'Sports']",
#  "['Adventure', 'Cartoon', 'Movie']",
#  "['Adventure', 'Casual', 'RPG', '']",
#  "['', 'Simulation', 'VR']",
#  "['Action', 'Indie', 'Casual', 'Simulation', 'Sports', 'VR']",
#  "['Action', 'RPG', 'Adventure', 'Action RPG', 'Isometric', 'Historical']",
#  "['', 'Indie', 'Simulation']",
#  "['Action', '', 'Racing', 'Sports']",
#  "['Horror', 'Movie', 'Action-Adventure']",
#  "['Movie', 'Foreign', 'Action-Adventure']",
#  "['', 'RPG', 'Adventure', 'VR', 'Indie', 'Visual Novel', 'Anime', 'Sci-fi']",
#  "['Casual', 'Indie', 'Simulation', '']",
#  "['Action', 'Adventure', 'RPG', 'Gore', 'Violent', 'VR']",
#  "['VR', 'Simulation', 'Utilities', 'Video Production']",
#  "['', 'Indie', 'Casual', 'Action', 'Adventure', 'VR', 'Horror']",
#  "['Episodic', 'Comedy']",
#  "['', 'Action', 'Adventure', 'Casual', 'Simulation', 'Strategy', 'RPG', 'VR']",
#  "['Action', 'Adventure', 'Indie', 'Strategy', 'VR', 'Action-Adventure', '', 'Stealth']",
#  "['Action', 'Casual', 'Sports']",
#  "['', 'Action', 'Indie', 'Shooter', '', 'VR', 'Action-Adventure', 'Realistic', 'Violent', 'Movie', 'Casual', 'Strategy', 'FPS']",
#  "['Casual', 'RPG', 'Strategy', '']",
#  "['Action', 'Sports', 'Casual', 'VR']",
#  "['Historical', 'Documentary']",
#  "['VR', 'Casual', 'Indie', 'Massively ', 'Adventure', 'Sandbox']",
#  "['Action', 'Casual', 'Strategy', '']",
#  "['Sci-fi', 'Movie', 'Action-Adventure']",
#  "['Movie', 'Mystery', 'Drama']",
#  "['Martial Arts', 'Movie', 'Documentary']",
#  "['', 'Indie', 'Casual', 'Simulation', 'VR', 'Puzzle']",
#  "['Adventure', 'Casual', 'VR']",
#  "['Adventure', 'RPG', 'Simulation', 'Racing', 'Action', 'VR', 'Pirates', 'Shooter']",
#  "['Simulation', 'Casual', 'RPG', 'VR']",
#  "['Action', 'Adventure', 'Indie', 'Massively ', 'RPG', 'Simulation', '']",
#  "['Education', 'VR']",
#  "['', 'Racing', 'Simulation', 'Sports', '']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Sports']",
#  "['Action', 'Casual', '', 'Indie', 'Massively ']",
#  "['Action', 'Casual', 'Indie', 'Massively ']",
#  "['Action', 'Adventure', 'Simulation', 'VR']",
#  "['Action', 'Indie', 'Simulation', 'VR']",
#  "['Action', 'Sports', 'VR']",
#  "['', 'Indie', 'Racing', 'Sports']",
#  "['Indie', 'VR']",
#  "['Action', 'Adventure', 'Casual', '', 'Indie', 'Simulation', 'Sports', 'Strategy']",
#  "['', 'Indie', 'Action', 'RPG']",
#  "['Short', 'Comedy', 'Drama']",
#  "['Action', 'Simulation', 'Sports', 'Strategy']",
#  "['Adventure', 'Action', 'Anime', 'Episodic']",
#  "['Documentary']",
#  "['Adventure', 'Indie', 'VR', 'Exploration', 'Mystery']",
#  "['Simulation', 'Casual', 'Memes', 'VR', 'Psychological Horror']",
#  "['FPS', 'Action', 'Zombies', 'VR', 'Indie', 'Horror', 'Online Co-Op', 'Survival Horror', 'Co-op']",
#  "['Action', 'Adventure', 'Casual', 'Massively ']",
#  "['Action', 'Adventure', '', 'Sports', 'Strategy']",
#  "['Racing', 'Simulation', 'Sports', '', '', '', 'Open World', 'Online Co-Op']",
#  "['Adventure', 'Indie', 'Puzzle', 'VR']",
#  "['Racing', 'Casual', 'Sports', 'Indie', 'Simulation', 'Action']",
#  "['Casual', 'Racing', 'VR']",
#  "['', 'Animation & Modeling', 'Design & Illustration', 'Utilities', 'VR']",
#  "['', 'Action', 'Indie', 'Casual', 'Simulation', 'VR']",
#  "['Video Production', 'Utilities', 'VR']",
#  "['Simulation', 'Driving', 'Open World', 'Realistic', '', 'Racing', 'Indie', '', 'Physics', '', 'Moddable', 'Family Friendly', 'Adventure', 'VR']",
#  "['Adventure', 'Strategy', 'Action', 'VR']",
#  "['Action', 'RPG', 'Massively ', 'Casual', 'Indie', 'Simulation', 'Space', 'VR']",
#  "['Adventure', '', 'Casual', 'VR', 'Story Rich', 'Sci-fi']",
#  "['Photo Editing']",
#  "['Strategy', 'Action', 'Adventure', 'VR']",
#  "['', 'Indie', 'Casual', 'Action', 'Strategy', 'Simulation', 'VR']",
#  "['Strategy', 'Tower Defense', 'VR']",
#  "['', 'Casual', 'Simulation', 'Music', 'VR']",
#  "['', 'Simulation', 'Indie', 'Strategy', 'VR', 'God Game']",
#  "['Education', '', 'Family Friendly', 'Video Production', 'VR', 'Casual', 'Atmospheric', '']",
#  "['Action', '', 'Indie', 'Simulation']",
#  "['Anime', 'Episodic', 'Movie']",
#  "['', 'Strategy', 'Action']",
#  "['Action', '', 'Indie', 'Massively ', 'RPG', '']",
#  "['Action', 'Adventure', 'Indie', 'Simulation', 'VR']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Simulation', '']",
#  "['Casual', '', 'Massively ', 'Strategy', '']",
#  "['Action', 'Casual', '', 'RPG']",
#  "['VR', 'Sports', 'Indie', 'Simulation']",
#  "['', 'Adventure', 'Indie', 'Action', 'VR']",
#  "['Casual', 'Indie', 'Adventure', 'Family Friendly', 'Cute', 'VR']",
#  "['Movie', 'Drama', 'Thriller']",
#  "['Documentary', 'Sports']",
#  "['Documentary', 'Action', 'Sports']",
#  "['Movie', 'Romance', 'Drama', 'Music']",
#  "['Action', 'Casual', 'Simulation', 'Sports', 'Strategy']",
#  "['Casual', 'Indie', 'Massively ', 'RPG', '']",
#  "['Casual', 'Indie', 'VR']",
#  "['Audio Production', 'Design & Illustration', 'Utilities', 'Video Production']",
#  "['Simulation', 'VR', 'Pinball']",
#  "['Action', 'Casual', 'Indie', 'Massively ', 'Simulation', 'Sports']",
#  "['Casual', 'Indie', 'RPG', '']",
#  "['', 'Action', 'VR', '', 'Competitive', 'Indie']",
#  "['Utilities', 'Video Production', 'Photo Editing', 'Animation & Modeling', 'Audio Production', 'Education', 'Training', 'Design & Illustration', 'Web Publishing', 'VR']",
#  "['Action', 'Indie', 'Casual', 'Sports', 'VR']",
#  "['Simulation', 'Indie', 'Sandbox', 'Building', 'Management', '', 'VR']",
#  "['Adventure', 'Simulation', '']",
#  "['Movie', 'Sci-fi', 'Action', 'Classic']",
#  "['Movie', 'Sci-fi', 'Action-Adventure', 'Classic']",
#  "['Simulation', '', 'VR']",
#  "['Indie', 'Casual', 'Adventure', 'Puzzle', 'VR', 'Horror']",
#  "['VR', '', 'Shooter', '', 'Arena Shooter', 'Action', 'FPS', '', 'Replay Value']",
#  "['', 'Strategy', 'Indie', 'Casual', 'VR']",
#  "['Casual', 'Simulation', 'VR']",
#  "['Indie', 'Casual', 'Sports', 'VR']",
#  "['Sports', 'Pool', 'Adventure', 'VR']",
#  "['Action', 'Casual', 'Indie', 'Simulation', 'Strategy', '']",
#  "['Adventure', 'Casual', '', 'Indie', 'Simulation', 'Sports', 'Strategy']",
#  "['Casual', '', 'Massively ', 'Simulation', 'Sports']",
#  "['Adventure', '', 'RPG']",
#  "['Action', 'Simulation', 'RPG', 'VR']",
#  "['Action', 'Indie', 'Simulation', 'VR', '6DOF', 'Arena Shooter', 'FPS', 'Sci-fi']",
#  "['Casual', 'Simulation', 'Action', 'Sports', 'VR']",
#  "['Action', 'Cyberpunk', 'VR']",
#  "['Action', 'Adventure', 'VR']",
#  "['Casual', 'Indie', 'VR', 'Puzzle', 'Platformer', '', 'Adventure', 'Action', '', 'Sci-fi', 'Physics', 'Atmospheric', '', 'Comedy']",
#  "['', 'Action', 'Indie', 'Local Co-Op', 'VR']",
#  "['Action', 'Indie', 'Casual', 'Simulation', 'VR', 'Family Friendly']",
#  "['Action', 'Adventure', 'Casual', 'VR']",
#  "['Indie', 'Racing', 'RPG', 'Simulation']",
#  "['Movie', 'Comedy', 'Basketball']",
#  "['Movie', 'Drama', 'Action', 'Adventure', 'Action-Adventure']",
#  "['Movie', 'Drama', 'Martial Arts', 'Action']",
#  "['', 'Adventure', 'VR']",
#  "['', 'Action', 'Simulation', 'Indie', 'Casual', 'VR']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'RPG', 'Sports']",
#  "['Documentary', 'Gaming', 'Movie']",
#  "['Action', 'Adventure', 'Indie', 'Casual', 'Simulation', 'VR']",
#  "['Adventure', 'Indie', 'Casual', 'Puzzle', 'VR']",
#  "['Action', 'Adventure', 'Simulation', 'Physics', '3D Platformer', 'Puzzle-Platformer', 'VR']",
#  "['Simulation', 'Action', 'VR', 'Flight']",
#  "['Simulation', 'VR']",
#  "['', 'Indie', 'Strategy', '']",
#  "['', 'Casual', 'Simulation', 'Sports', 'Action', 'VR']",
#  "['', 'Action', 'Indie', 'Simulation', 'Destruction', 'VR', 'Arcade', 'Sandbox', '']",
#  "['Utilities', 'VR', 'Indie', 'Atmospheric']",
#  "['Indie', 'Action', 'VR', 'Shooter']",
#  "['Action', 'Adventure', 'Casual', 'VR', 'Puzzle', 'Drama']",
#  "['Utilities', 'Animation & Modeling', 'VR']",
#  "['Sports', 'VR']",
#  "['Education', 'VR', 'Simulation', 'Animation & Modeling']",
#  "['', 'Action', 'Casual', 'Indie', 'Strategy', 'VR']",
#  "['Simulation', 'Indie', 'Casual', 'VR']",
#  "['', 'Strategy', 'Indie', 'Simulation', 'RPG', 'VR', 'Card Game']",
#  "['Action', 'Casual', 'Indie', 'Sports', 'Rhythm', 'VR']",
#  "['Action', 'Simulation', 'Sports', 'VR']",
#  "['Action', 'Casual', 'Indie', 'RPG', 'Sports', 'Strategy', '']",
#  "['VR', 'Rhythm', 'Indie', 'Music', 'Action', 'Casual', 'Sports']",
#  "['Action', 'Indie', 'Simulation', 'Gore', 'Violent', 'VR']",
#  "['', 'Action', 'Indie', 'Casual', 'Sports']",
#  "['Indie', 'Massively ', 'RPG', 'Simulation', 'Strategy']",
#  "['Action', 'Indie', 'Sports', 'Strategy', '']",
#  "['Simulation', 'Sports', 'Indie', 'VR']",
#  "['RPG', 'Indie', 'Action', 'Casual', 'Simulation', 'Adventure', 'VR']",
#  "['Adventure', 'Casual', 'Sports', 'VR']",
#  "['Indie', 'Casual', 'Racing', 'Action', 'Family Friendly', 'VR']",
#  "['Indie', 'Casual', 'Puzzle', 'Cute', 'Family Friendly', 'Action', 'VR']",
#  "['', 'Strategy', 'Indie', 'Casual', 'Simulation', 'VR', 'Education', 'Sandbox']",
#  "['Gaming', 'Episodic', 'Drama', 'Game Development', 'Documentary']",
#  "['Movie', 'Action', 'War', 'World War II']",
#  "['Design & Illustration', 'Photo Editing', 'Training', 'Utilities', 'Video Production']",
#  "['Audio Production', 'Training', 'Utilities', 'Video Production']",
#  "['Action', 'Adventure', 'Casual', '', 'Indie', 'RPG']",
#  "['RPG', 'Action', 'VR']",
#  "['Action', 'Adventure', 'VR', 'Shooter', '', 'Casual', 'Sports', 'Fantasy', 'Cartoon']",
#  "['Racing', 'Action', 'Indie', 'Simulation', 'VR']",
#  "['Casual', '', 'Indie', 'RPG', 'Simulation', 'Strategy', '']",
#  "['Action', 'Sci-fi', 'Movie']",
#  "['Adventure', 'Simulation', 'VR', '']",
#  "['Action', 'Adventure', 'Casual', 'Simulation', 'VR']",
#  "['', '', 'VR', 'Massively ', 'Casual', 'Adventure', 'Simulation', 'Anime', 'Sports', 'Memes', 'Psychological Horror', 'MMORPG', '', '']",
#  "['Animation & Modeling', 'Design & Illustration', 'Education', 'Training', 'Video Production', 'Web Publishing']",
#  "['', 'Puzzle', 'Co-op', 'Horror', '', 'Adventure', 'Online Co-Op', 'Co-op Campaign', 'Action', '', '', 'Survival', 'VR', 'Atmospheric', 'Mystery', 'Indie', 'Psychological Horror', '', '', 'Open World']",
#  "['', 'Simulation', 'Sports', 'VR', 'Action']",
#  "['Adventure', 'Indie', 'Simulation', 'VR', 'Puzzle', 'Space', 'Space Sim']",
#  "['Indie', 'Action', 'Casual', 'VR', 'Tower Defense']",
#  "['Action', '', 'Massively ', 'Simulation', '']",
#  "['Action', 'Adventure', 'Casual', 'Indie', 'Racing', 'Sports']",
#  "['Casual', 'Indie', 'Sports', '']",
#  "['', 'Adventure', 'Puzzle', 'Horror', 'Psychological Horror', 'Indie', 'Choose Your Own Adventure', 'Dark Fantasy', 'Psychological', 'Dark Comedy', 'Action-Adventure', 'Comedy']",
#  "['', 'Indie', 'VR', 'Arcade']",
#  "['Action', 'Indie', 'Horror', 'VR', 'Atmospheric', 'Survival', 'Survival Horror']",
#  "['', 'Action', 'Casual', 'Simulation', 'VR']",
#  "['Massively ', 'Racing', 'Simulation', 'Sports']",
#  "['Casual', 'RPG', 'Strategy']",
#  "['', 'Design & Illustration', 'VR']",
#  "['', 'Action', 'Indie', 'Sports', 'VR']",
#  "['Design & Illustration', 'Photo Editing', 'Video Production']",
#  "['Education', 'Design & Illustration', 'Animation & Modeling', 'VR']",
#  "['Action', 'Adventure', 'Indie', 'Casual', 'Strategy', 'VR']",
#  "['Animation & Modeling', 'Design & Illustration', 'Education', 'Training', 'Utilities', 'Video Production', 'Web Publishing']",
#  "['Action', '', 'Indie', 'Racing', 'Sports', 'Strategy']",
#  "['', 'Sports', 'Simulation', 'Action', 'VR']",
#  ...]

# %%
# Convertir los datos de la columna 'tags' a cadenas
df_games_clean[['genres', 'tags', 'publisher', 'app_name', 'developer']] = df_games_clean[['genres', 'tags', 'publisher', 'app_name', 'developer']].astype(str)

# %%
# Limpiamos los textos de nuestro dataframe. Creamos función para convertir listas a cadenas y limpiar el texto
def clean_text(text):
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)
    return cleaned_text
# Aplicar la función a las columnas especificadas
#['genres', 'tags', 'specs', 'publisher', 'app_name', 'developer']
columns_to_clean = ['genres', 'tags', 'publisher', 'app_name', 'developer']
for column in columns_to_clean:
    df_games_clean[column] = df_games_clean[column].apply(clean_text)

# %%
df_games_clean.head()
# Out:
#             publisher                                   genres  \
# 88310       Kotoshiro  Action Casual Indie Simulation Strategy
# 88311  Making Fun Inc                       Indie RPG Strategy
# 88312     Poolianscom          Casual  Indie Simulation Sports
# 88313                                  Action Adventure Casual
# 88314            None               Action Indie Casual Sports
#
#                     app_name release_date  \
# 88310    Lost Summoner Kitty   2018-01-04
# 88311              Ironbound   2018-01-04
# 88312  Real Pool D  Poolians   2017-07-24
# 88313                          2017-12-07
# 88314          Log Challenge         None
#
#                                                     tags         price  \
# 88310            Strategy Action Indie Casual Simulation          4.99
# 88311  Free to Play Strategy Indie RPG Card Game Trad...  Free To Play
# 88312  Free to Play Simulation Sports Casual Indie Mu...  Free to Play
# 88313                            Action Adventure Casual          0.99
# 88314                         Action Indie Casual Sports          2.99
#
#              id         developer
# 88310  761140.0         Kotoshiro
# 88311  643980.0  Secret Level SRL
# 88312  670290.0       Poolianscom
# 88313  767400.0
# 88314  773570.0              None

# %%
# Transformar los "Free to play" en "Free"
df_games_clean['price'] = df_games_clean['price'].replace('(?i)Free to Play', 'Free', regex=True)

# %%
# Actualizar la columna 'price' a 'Free' donde 'tags' contiene 'Free to Play'
df_games_clean.loc[df_games_clean['tags'].str.contains('Free to Play', na=False), 'price'] = 'Free'

# %%
df_games_clean.head()
# Out:
#             publisher                                   genres  \
# 88310       Kotoshiro  Action Casual Indie Simulation Strategy
# 88311  Making Fun Inc                       Indie RPG Strategy
# 88312     Poolianscom          Casual  Indie Simulation Sports
# 88313                                  Action Adventure Casual
# 88314            None               Action Indie Casual Sports
#
#                     app_name release_date  \
# 88310    Lost Summoner Kitty   2018-01-04
# 88311              Ironbound   2018-01-04
# 88312  Real Pool D  Poolians   2017-07-24
# 88313                          2017-12-07
# 88314          Log Challenge         None
#
#                                                     tags price        id  \
# 88310            Strategy Action Indie Casual Simulation  4.99  761140.0
# 88311  Free to Play Strategy Indie RPG Card Game Trad...  Free  643980.0
# 88312  Free to Play Simulation Sports Casual Indie Mu...  Free  670290.0
# 88313                            Action Adventure Casual  0.99  767400.0
# 88314                         Action Indie Casual Sports  2.99  773570.0
#
#               developer
# 88310         Kotoshiro
# 88311  Secret Level SRL
# 88312       Poolianscom
# 88313
# 88314              None

# %%
# Reemplazar todos los valores vacíos ('') en el df_reviews_final por NaN
df_games_clean.replace('', np.nan, inplace=True)
df_games_clean.replace('None', np.nan, inplace=True)

# %%
df_games_clean.head()
# Out:
#             publisher                                   genres  \
# 88310       Kotoshiro  Action Casual Indie Simulation Strategy
# 88311  Making Fun Inc                       Indie RPG Strategy
# 88312     Poolianscom          Casual  Indie Simulation Sports
# 88313             NaN                  Action Adventure Casual
# 88314             NaN               Action Indie Casual Sports
#
#                     app_name release_date  \
# 88310    Lost Summoner Kitty   2018-01-04
# 88311              Ironbound   2018-01-04
# 88312  Real Pool D  Poolians   2017-07-24
# 88313                    NaN   2017-12-07
# 88314          Log Challenge         None
#
#                                                     tags price        id  \
# 88310            Strategy Action Indie Casual Simulation  4.99  761140.0
# 88311  Free to Play Strategy Indie RPG Card Game Trad...  Free  643980.0
# 88312  Free to Play Simulation Sports Casual Indie Mu...  Free  670290.0
# 88313                            Action Adventure Casual  0.99  767400.0
# 88314                         Action Indie Casual Sports  2.99  773570.0
#
#               developer
# 88310         Kotoshiro
# 88311  Secret Level SRL
# 88312       Poolianscom
# 88313               NaN
# 88314               NaN

# %%
# revisamos nuevamente los missing values

# Usamos función missing_values_table que ya creamos anteriormente
miss_df_games_clean = missing_values_table(df_games_clean)
print('\nValores faltantes del dataset df_games_clean:')
print(miss_df_games_clean)
# Out:
# El dataframe seleccionado tiene 8 columnas.
# Hay 8 columnas que tienen valores faltantes.
#
# Valores faltantes del dataset df_games_clean:
#               Valores Faltantes  % de Valores Totales
# publisher                  8100                  25.2
# developer                  3351                  10.4
# release_date               2067                   6.4
# price                      1173                   3.7
# genres                      167                   0.5
# tags                        163                   0.5
# app_name                     26                   0.1
# id                            2                   0.0

# %% [markdown]
# *Dado que los nulos son significativos en el caso de publisher. developer y release_data, en el EDA buscaremos estartegias para tratarlos, ya que eliminarlos desde ya eliminaría gran parte de la información de nuestro dataframe.*

# %% [markdown]
# *Sólo se deja año en la columna release_date de la nueva base de datos y se ajusta el tipo de dato precio a float*

# %%
# Filtrar filas donde 'price' sea 'Free' o nulo
nulos_price = df_games_clean[df_games_clean['price'].isnull()]

# %%
# Mostrar el resultado
nulos_price [['tags', 'price']].sample(10)
# Out:
#                                                      tags price
# 93707                 Design  Illustration Web Publishing  None
# 116492                                          Adventure  None
# 118734                                         Action RPG  None
# 108784                             Action Indie Casual VR  None
# 109561                                Action Indie Sports  None
# 114274                                                NaN  None
# 102702                                    Adventure Indie  None
# 95047                              Action Indie VR Flight  None
# 101259  Casual Adventure Visual Novel Anime Sexual Con...  None
# 104055                                Action Indie Casual  None

# %%
df_games_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32135 entries, 88310 to 120444
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24035 non-null  object
#  1   genres        31968 non-null  object
#  2   app_name      32109 non-null  object
#  3   release_date  30068 non-null  object
#  4   tags          31972 non-null  object
#  5   price         30962 non-null  object
#  6   id            32133 non-null  float64
#  7   developer     28784 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 2.2+ MB

# %% [markdown]
# *Normalizamos la columa price*

# %%
# Se define una función lambda para convertir a 0 si es string, de lo contrario mantener el valor original
replace_string_with_zero = lambda x: 0 if isinstance(x, str) else x

# Aplicar la función lambda a la columna 'price'
df_games_clean['price'] = df_games_clean['price'].apply(replace_string_with_zero)

# Verificar los cambios
print(df_games_clean['price'])
# Out:
# 88310     4.99
# 88311     0.00
# 88312     0.00
# 88313     0.99
# 88314     2.99
#           ...
# 120440    1.99
# 120441    4.99
# 120442    1.99
# 120443    4.99
# 120444    4.99
# Name: price, Length: 32135, dtype: float64

# %% [markdown]
# *En columna release_data, sólo dejamos el año:*

# %%
df_games_clean=df_games_clean.copy()
# Normalizar la columna 'release_date'
df_games_clean['release_date'] = df_games_clean['release_date'].str.extract(r'(\d{4})')

df_games_clean
# Out:
#              publisher                                   genres  \
# 88310        Kotoshiro  Action Casual Indie Simulation Strategy
# 88311   Making Fun Inc                       Indie RPG Strategy
# 88312      Poolianscom          Casual  Indie Simulation Sports
# 88313              NaN                  Action Adventure Casual
# 88314              NaN               Action Indie Casual Sports
# ...                ...                                      ...
# 120440  GhostRUS Games         Casual Indie Simulation Strategy
# 120441          Sacada                    Casual Indie Strategy
# 120442    Laush Studio                  Indie Racing Simulation
# 120443        SIXNAILS                             Casual Indie
# 120444             NaN     Adventure Indie Action Simulation VR
#
#                        app_name release_date  \
# 88310       Lost Summoner Kitty         2018
# 88311                 Ironbound         2018
# 88312     Real Pool D  Poolians         2017
# 88313                       NaN         2017
# 88314             Log Challenge          NaN
# ...                         ...          ...
# 120440           Colony On Mars         2018
# 120441  LOGistICAL South Africa         2018
# 120442            Russian Roads         2018
# 120443        EXIT   Directions         2017
# 120444              Maze Run VR          NaN
#
#                                                      tags  price        id  \
# 88310             Strategy Action Indie Casual Simulation   4.99  761140.0
# 88311   Free to Play Strategy Indie RPG Card Game Trad...   0.00  643980.0
# 88312   Free to Play Simulation Sports Casual Indie Mu...   0.00  670290.0
# 88313                             Action Adventure Casual   0.99  767400.0
# 88314                          Action Indie Casual Sports   2.99  773570.0
# ...                                                   ...    ...       ...
# 120440                   Strategy Indie Casual Simulation   1.99  773640.0
# 120441                              Strategy Indie Casual   4.99  733530.0
# 120442                            Indie Simulation Racing   1.99  610660.0
# 120443  Indie Casual Puzzle Singleplayer Atmospheric R...   4.99  658870.0
# 120444  Early Access Adventure Indie Action Simulation VR   4.99  681550.0
#
#                        developer
# 88310                  Kotoshiro
# 88311           Secret Level SRL
# 88312                Poolianscom
# 88313                        NaN
# 88314                        NaN
# ...                          ...
# 120440           Nikita GhostRUS
# 120441                    Sacada
# 120442  Laush Dmitriy Sergeevich
# 120443               xropistevns
# 120444                       NaN
#
# [32135 rows x 8 columns]

# %%
df_games_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32135 entries, 88310 to 120444
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24035 non-null  object
#  1   genres        31968 non-null  object
#  2   app_name      32109 non-null  object
#  3   release_date  29967 non-null  object
#  4   tags          31972 non-null  object
#  5   price         30962 non-null  float64
#  6   id            32133 non-null  float64
#  7   developer     28784 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 2.2+ MB

# %% [markdown]
# *Guardamos finalmente los tres dataframes en formato parquet*

# %%
df_games_clean.to_parquet('Steam_games.parquet', index=False)
df_reviews_final.to_parquet('Reviews.parquet', index=False)
df_items_final.to_parquet('Items.parquet', index=False)
